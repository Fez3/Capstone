# %% [markdown]
# ## Model Version 5

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import sklearn 
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import sklearn.metrics as metrics
import xgboost as xgb
from xgboost import XGBClassifier
from xgboost import plot_importance
import time
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

# %%
df = pd.read_csv("final.df.csv")
df.shape
# Out:
# (200000, 80)

# %%
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 200)
df.describe()
# need to check (distribution extreme.. check after initial modeling) :  
#    dti, total_rec_late_fee, recoveries, tot_coll_amt, mths_since_rcnt_il, il_util, max_bal_bc, avg_cur_bal,
#    delinq_amnt, mo_sin_rcnt_rev_tl_op, mo_sin_rcnt_tl, mths_since_recent_revol_delinq, tax_liens
# Out:
#            loan_amnt       int_rate    installment    annual_inc            dti    delinq_2yrs  inq_last_6mths  mths_since_last_delinq       open_acc        pub_rec     revol_bal     revol_util  \
# count  200000.000000  200000.000000  200000.000000  2.000000e+05  200000.000000  200000.000000   200000.000000           200000.000000  200000.000000  200000.000000  2.000000e+05  200000.000000
# mean    14740.615375      14.047924     445.564543  7.432490e+04      18.931042       0.326485        0.694805               38.589950      11.683355       0.226445  1.590229e+04      52.740852
# std      8752.102580       4.954058     262.118049  7.020791e+04      11.675555       0.886051        0.964933               21.663606       5.529451       0.631672  2.076584e+04      24.399791
# min       500.000000       5.310000      14.010000  0.000000e+00      -1.000000       0.000000        0.000000                0.000000       0.000000       0.000000  0.000000e+00       0.000000
# 25%      8000.000000      10.640000     257.200000  4.500000e+04      12.350000       0.000000        0.000000               22.000000       8.000000       0.000000  5.936000e+03      34.600000
# 50%     12625.000000      13.490000     382.360000  6.300000e+04      18.330000       0.000000        0.000000               36.000000      11.000000       0.000000  1.108700e+04      53.300000
# 75%     20000.000000      16.990000     587.550000  9.000000e+04      24.830000       0.000000        1.000000               55.000000      14.000000       0.000000  1.940200e+04      71.600000
# max     40000.000000      30.990000    1717.630000  1.099920e+07     999.000000      21.000000        8.000000              202.000000      80.000000      86.000000  1.190046e+06     182.800000
#
#            total_acc    total_pymnt  total_rec_int  total_rec_late_fee     recoveries  last_pymnt_amnt  last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  acc_now_delinq  \
# count  200000.000000  200000.000000  200000.000000       200000.000000  200000.000000    200000.000000         200000.000000        200000.000000               200000.000000   200000.000000
# mean       24.888360   12636.221310    2478.097381            2.624044     560.785900      3799.395097            641.761105           610.148025                    0.018800        0.005245
# std        12.065927    9763.746055    2626.966900           13.561922    1410.832467      6281.502295             89.661439           169.790827                    0.152829        0.079168
# min         2.000000       0.000000       0.000000            0.000000       0.000000         0.000000              0.000000             0.000000                    0.000000        0.000000
# 25%        16.000000    5411.899123     786.697500            0.000000       0.000000       318.790000            564.000000           560.000000                    0.000000        0.000000
# 50%        23.000000   10080.124295    1632.645000            0.000000       0.000000       652.410000            649.000000           645.000000                    0.000000        0.000000
# 75%        32.000000   17291.974973    3179.242500            0.000000     449.050000      4799.417500            714.000000           710.000000                    0.000000        0.000000
# max       173.000000   62687.030890   27687.030000         1188.830000   37153.460000     41096.620000            850.000000           845.000000                    9.000000        6.000000
#
#         tot_coll_amt   tot_cur_bal    open_acc_6m    open_act_il    open_il_12m    open_il_24m  mths_since_rcnt_il  total_bal_il        il_util    open_rv_12m    open_rv_24m     max_bal_bc  \
# count  200000.000000  2.000000e+05  200000.000000  200000.000000  200000.000000  200000.000000       200000.000000  2.000000e+05  200000.000000  200000.000000  200000.000000  200000.000000
# mean      230.022100  1.334342e+05       1.050920       2.714855       0.873715       1.915005           19.761910  3.351007e+04      70.205415       1.262295       2.713755    5505.012450
# std      1775.613015  1.492501e+05       1.189981       2.953508       1.056642       2.005857           25.708152  4.046119e+04      23.289368       1.358994       2.337575    5174.260522
# min         0.000000  0.000000e+00       0.000000       0.000000       0.000000       0.000000            0.000000  0.000000e+00       0.000000       0.000000       0.000000       0.000000
# 25%         0.000000  2.936775e+04       0.000000       1.000000       0.000000       0.000000            6.000000  8.806750e+03      57.000000       0.000000       1.000000    2213.000000
# 50%         0.000000  7.298800e+04       1.000000       2.000000       1.000000       1.000000           12.000000  2.232000e+04      74.000000       1.000000       2.000000    4224.000000
# 75%         0.000000  1.972862e+05       2.000000       3.000000       1.000000       3.000000           22.000000  4.353500e+04      86.000000       2.000000       4.000000    7206.000000
# max    199433.000000  3.258254e+06      16.000000      48.000000      20.000000      39.000000          446.000000  1.547285e+06     558.000000      22.000000      45.000000  301210.000000
#
#             all_util  total_rev_hi_lim         inq_fi    total_cu_tl   inq_last_12m  acc_open_past_24mths    avg_cur_bal  bc_open_to_buy        bc_util  chargeoff_within_12_mths    delinq_amnt  \
# count  200000.000000      2.000000e+05  200000.000000  200000.000000  200000.000000         200000.000000  200000.000000   200000.000000  200000.000000             200000.000000  200000.000000
# mean       61.995210      3.119424e+04       1.167065       1.669000       2.407435              4.898570   12652.200355     9305.872275      61.043219                  0.008975      16.915020
# std        19.674457      3.094635e+04       1.683867       2.932574       2.615008              3.280455   15288.478032    14277.046880      28.251856                  0.104616     943.077677
# min         0.000000      0.000000e+00       0.000000       0.000000       0.000000              0.000000       0.000000        0.000000       0.000000                  0.000000       0.000000
# 25%        50.000000      1.360000e+04       0.000000       0.000000       1.000000              3.000000    3009.000000     1327.000000      39.600000                  0.000000       0.000000
# 50%        64.000000      2.320000e+04       1.000000       0.000000       2.000000              4.000000    6807.000000     4280.000000      64.700000                  0.000000       0.000000
# 75%        76.000000      3.860000e+04       2.000000       2.000000       3.000000              7.000000   17392.250000    11166.000000      86.000000                  0.000000       0.000000
# max       168.000000      1.314900e+06      28.000000      48.000000      32.000000             50.000000  497484.000000   293031.000000     190.600000                  6.000000  249925.000000
#
#        mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl       mort_acc  mths_since_recent_bc  mths_since_recent_inq  mths_since_recent_revol_delinq  \
# count       200000.000000         200000.000000          200000.000000   200000.000000  200000.000000         200000.000000          200000.000000                    200000.00000
# mean           123.496620            177.572560              12.592685        7.572270       1.583020             23.051050               7.020060                        41.13807
# std             53.847389             94.626771              15.829046        8.539039       1.974375             30.106178               6.059382                        21.84772
# min              0.000000              3.000000               0.000000        0.000000       0.000000              0.000000               0.000000                         0.00000
# 25%             93.000000            114.000000               4.000000        3.000000       0.000000              6.000000               2.000000                        24.00000
# 50%            128.000000            160.000000               8.000000        5.000000       1.000000             13.000000               5.000000                        39.00000
# 75%            151.000000            226.000000              15.000000       10.000000       3.000000             27.000000              11.000000                        59.00000
# max            724.000000            804.000000             324.000000      314.000000      32.000000            538.000000              25.000000                       202.00000
#
#        num_accts_ever_120_pd  num_actv_bc_tl    num_bc_sats      num_bc_tl  num_rev_tl_bal_gt_0   num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# count          200000.000000   200000.000000  200000.000000  200000.000000        200000.000000  200000.000000       200000.000000       200000.000000   200000.000000     200000.000000
# mean                0.522660        3.702345       4.719860       7.997870             5.726970       0.003425            0.088390            2.271730       94.162227         46.697567
# std                 1.333422        2.268906       2.960616       4.750692             3.267695       0.062636            0.485539            1.894223        8.728537         36.143285
# min                 0.000000        0.000000       0.000000       0.000000             0.000000       0.000000            0.000000            0.000000        6.700000          0.000000
# 25%                 0.000000        2.000000       3.000000       5.000000             3.000000       0.000000            0.000000            1.000000       91.300000         14.300000
# 50%                 0.000000        3.000000       4.000000       7.000000             5.000000       0.000000            0.000000            2.000000       97.900000         50.000000
# 75%                 0.000000        5.000000       6.000000      10.000000             7.000000       0.000000            0.000000            3.000000      100.000000         75.000000
# max                34.000000       30.000000      46.000000      61.000000            39.000000       4.000000           20.000000           25.000000      100.000000        100.000000
#
#        pub_rec_bankruptcies      tax_liens  total_bc_limit  fico_range_mean  sub_grade_num  emp_length_num
# count         200000.000000  200000.000000   200000.000000    200000.000000  200000.000000   200000.000000
# mean               0.142080       0.054800    20540.207830       695.489473      12.822720        5.946410
# std                0.386451       0.436312    20559.740281        30.408820       6.669401        3.699005
# min                0.000000       0.000000        0.000000       662.000000       1.000000        0.000000
# 25%                0.000000       0.000000     7500.000000       672.000000       8.000000        2.000000
# 50%                0.000000       0.000000    14400.000000       687.000000      12.000000        6.000000
# 75%                0.000000       0.000000    26500.000000       712.000000      17.000000       10.000000
# max                8.000000      85.000000   760000.000000       847.500000      35.000000       10.000000

# %% [markdown]
# ### Extreme outlier

# %%
df_plot = df
label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(df_plot['loan_status'])
df_plot['loan_status'] = label_encoder.transform(df_plot['loan_status'])

# %%
##### "dti" distribution (Outlier) #####
plt.figure(figsize=(10,4))
plt.rcParams['agg.path.chunksize'] = 1000000
plt.subplot(1,2,1)
plt.title('[ Scatter plot for dti & loan_Status ]', fontweight="bold")
plt.scatter('dti', 'loan_status', data=df_plot)
plt.xlabel('dti')
plt.ylabel('Loan Status')

plt.subplot(1,2,2)
plt.hist(df['dti'], bins=1000, color="blue")
plt.title('[ Histogram for dti ]', fontweight="bold")
plt.xlabel('dti')

df.dti.unique().shape
print('shape of data(dti>=600) :', df[df['dti'] >= 600].shape)
# Out:
# shape of data(dti>=600) : (10, 80)

# %%
##### "total_rec_late_fee" distribution (Outlier) #####
plt.figure(figsize=(10,4))
plt.rcParams['agg.path.chunksize'] = 1000000
plt.subplot(1,2,1)
plt.title('[ total_rec_late_fee & loan_Status ]', fontweight="bold")
plt.scatter('total_rec_late_fee', 'loan_status', data=df_plot)
plt.xlabel('total_rec_late_fee')
plt.ylabel('Loan Status')

plt.subplot(1,2,2)
plt.hist(df['total_rec_late_fee'], bins=50, color="blue")
plt.title('[ Histogram for total_rec_late_fee ]', fontweight="bold")
plt.xlabel('total_rec_late_fee')

df.dti.unique().shape
print('shape of data(total_rec_late_fee>=500) :', df[df['total_rec_late_fee'] >= 500].shape)
# Out:
# shape of data(total_rec_late_fee>=500) : (5, 80)

# %%
##### "tot_coll_amt" distribution (Outlier) #####
plt.figure(figsize=(10,4))
plt.rcParams['agg.path.chunksize'] = 1000000
plt.subplot(1,2,1)
plt.title('[ tot_coll_amt & loan_Status ]', fontweight="bold")
plt.scatter('tot_coll_amt', 'loan_status', data=df_plot)
plt.xlabel('tot_coll_amt')
plt.ylabel('Loan Status')

plt.subplot(1,2,2)
plt.hist(df['tot_coll_amt'], bins=80, color="blue")
plt.title('[ Histogram for tot_coll_amt ]', fontweight="bold")
plt.xlabel('tot_coll_amt')

df.dti.unique().shape
print('shape of data(tot_coll_amt>=100000) :', df[df['tot_coll_amt'] >= 100000].shape)
# Out:
# shape of data(tot_coll_amt>=100000) : (6, 80)

# %%
# outlier deletion :  dti (>=600, 10 counts)
print('before outlier(dti) removel : ', df.shape)
df = df[df['dti'] < 600]
print('after outlier(dti) removel : ', df.shape)

df = df[df['total_rec_late_fee'] < 500]
print('after outlier(total_rec_late_fee) removel : ', df.shape)

df = df[df['tot_coll_amt'] < 100000]
print('after outlier(tot_coll_amt) removel : ', df.shape)
# Out:
# before outlier(dti) removel :  (200000, 80)
# after outlier(dti) removel :  (199990, 80)
# after outlier(total_rec_late_fee) removel :  (199985, 80)
# after outlier(tot_coll_amt) removel :  (199979, 80)

# %%
df = df.drop(['recoveries', 'last_pymnt_amnt','last_fico_range_high','last_fico_range_low','total_pymnt'], axis=1)

# %% [markdown]
# ### 'State' delete (Too many categories & Not important)

# %%
df = df.drop(['addr_state'], axis=1)

# %% [markdown]
# ### dummification for categorical variables

# %%
print(df.dtypes.value_counts())
# Out:
# int64      52
# float64    13
# object      9
# dtype: int64

# %%
x_old = df[df.columns.difference(['loan_status'])]
y = df[['loan_status']]

# %%
x = pd.get_dummies(x_old, drop_first=True)

# %% [markdown]
# ## Modeling with Top 42 important Variables

# %%
## Top 42 variables
top42_var = ['total_rec_int','installment','loan_amnt','int_rate','total_rec_late_fee','debt_settlement_flag_Y',
'term_ 60 months','annual_inc','mo_sin_old_rev_tl_op','sub_grade_num','dti','num_rev_tl_bal_gt_0','avg_cur_bal',
'total_rev_hi_lim','bc_open_to_buy','fico_range_mean','total_bc_limit','acc_open_past_24mths',
'home_ownership_RENT','tot_cur_bal','mort_acc','open_rv_24m',
             
'total_acc','grade_D','mths_since_recent_inq','max_bal_bc','revol_bal','mo_sin_old_il_acct','revol_util',
'bc_util','total_bal_il','mths_since_rcnt_il','open_acc_6m','il_util','mths_since_last_delinq',
'percent_bc_gt_75','inq_last_6mths','all_util','mths_since_recent_bc','verification_status_Verified',
'purpose_small_business','home_ownership_MORTGAGE']

# %%
x = x[top42_var]

# %%
x.shape
# Out:
# (199979, 42)

# %% [markdown]
# ### x,y split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### 1. Logistic Regression

# %%
log = LogisticRegression()

log.fit(x_train, y_train)

print('training prediction accuracy :  %.2f' % log.score(x_train, y_train))
print('test prediction accuracy :  %.2f' % log.score(x_test, y_test))
print('** test pred (initial model) : ', 0.69)
# Out:
# training prediction accuracy :  0.69
# test prediction accuracy :  0.68
# ** test pred (initial model) :  0.69

# %%
## same logic (for checking)
lr_log = LogisticRegression()
lr_log.fit(x_train, y_train)
lr_pred = lr_log.predict(x_test)

print('logistic regression accuracy : %.2f' % accuracy_score(y_test, lr_pred))
print('** test pred (initial model) : ', 0.69)
# Out:
# logistic regression accuracy : 0.68
# ** test pred (initial model) :  0.69

# %%
test_pred_prob = lr_log.predict_proba(x_test)
print(roc_auc_score(y_test, test_pred_prob[:,1]))
print('** test pred (initial model) : ', 0.747396965817424)
# Out:
# 0.7475984569076144
# ** test pred (initial model) :  0.747396965817424

# %%
# calculate the fpr and tpr for all thresholds of the classification
lr_test_pred_prob = lr_log.predict_proba(x_test)
lr_preds = lr_test_pred_prob[:,1]
lr_fpr, lr_tpr, lr_threshold = metrics.roc_curve(y_test, lr_preds)
lr_roc_auc = metrics.auc(lr_fpr, lr_tpr)

# method I: plt
plt.title('Logistic Regression ROC')
plt.plot(lr_fpr, lr_tpr, 'b', label = 'AUC = %0.2f' % lr_roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ### 2. Random Forest

# %% [markdown]
# #### * Before Tuning

# %%
start_time = time.time()

rf_clf = RandomForestClassifier(random_state=1)
rf_clf.fit(x_train, y_train)
rf_pred = rf_clf.predict(x_test)

accuracy = accuracy_score(y_test, rf_pred)
print('rf accuracy : {0:.4f}' .format(accuracy))
print('** accuracy (initial model) : ', 0.6685)
print('RF running time : {0:.1f} seconds '.format(time.time()-start_time))
# Out:
# rf accuracy : 0.6823
# ** accuracy (initial model) :  0.6685
# RF running time : 8.4 seconds

# %% [markdown]
# #### * Hyper Parameter tuning

# %%
### It takes very long ###

start_time = time.time()

rf2_clf = RandomForestClassifier(random_state=1)
rf_params = {
    'n_estimators': [100,300],    
    'max_depth': [6,8,10],
    'min_samples_leaf': [8,12,18],
    'min_samples_split': [8,12,18],
    "random_state": [1]
}

# GridSearchCV
rf_grid_cv = GridSearchCV(rf2_clf, param_grid=rf_params, cv=5)
rf_grid_cv.fit(x_train,y_train)

print('best parameter:\n', rf_grid_cv.best_params_)
print('best prediction accuracy: {0:.4f}'.format(rf_grid_cv.best_score_))
# Out:
# best parameter:
#  {'max_depth': 10, 'min_samples_leaf': 8, 'min_samples_split': 18, 'n_estimators': 100, 'random_state': 1}
# best prediction accuracy: 0.7089

# %%
### prediction by best param (auto)
rf3_pred = rf_grid_cv.best_estimator_.predict(x_test)

print('rf3 accuracy : {0:.4f}' .format(accuracy_score(y_test, rf3_pred)))
print('** accuracy (initial model) : ', 0.7011)
print('RF tuning & running time : {0:.1f} seconds '.format(time.time()-start_time))
# Out:
# rf3 accuracy : 0.7095
# ** accuracy (initial model) :  0.7011
# RF tuning & running time : 12136.7 seconds

# %%
### test with best param + n_estimators increase (Pre-determined params,...)
rf3_clf = RandomForestClassifier(n_estimators=300, max_depth=10, min_samples_leaf=8,
                                min_samples_split=8, random_state=1)
rf3_clf.fit(x_train, y_train)
rf3_pred = rf3_clf.predict(x_test)

print('rf3 accuracy : {0:.4f}' .format(accuracy_score(y_test, rf3_pred)))
print('** accuracy (initial model) : ', 0.7011)
# Out:
# rf3 accuracy : 0.7098
# ** accuracy (initial model) :  0.7011

# %%
rf_test_pred_prob = rf3_clf.predict_proba(x_test)
print('rf ROC_AUC Score :', roc_auc_score(y_test, rf_test_pred_prob[:,1]))
# Out:
# rf ROC_AUC Score : 0.778958334115954

# %%
# calculate the fpr and tpr for all thresholds of the classification
rf_test_pred_prob = rf3_clf.predict_proba(x_test)
rf_preds = rf_test_pred_prob[:,1]
rf_fpr, rf_tpr, rf_threshold = metrics.roc_curve(y_test, rf_preds)
rf_roc_auc = metrics.auc(rf_fpr, rf_tpr)

# method I: plt
plt.title('Random Forest ROC')
plt.plot(rf_fpr, rf_tpr, 'b', label = 'AUC = %0.2f' % rf_roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
rf_feature_imp = rf3_clf.feature_importances_
rf_feature_imp = pd.Series(rf_feature_imp, index=x_train.columns)
rf_feature_top20 = rf_feature_imp.sort_values(ascending=False)[:20]
rf_feature_top40_rf = rf_feature_imp.sort_values(ascending=False)[:40]

print(rf_feature_top20)

plt.figure(figsize=(8,6))
plt.title('Feature Importance (top20)')
sns.barplot(x=rf_feature_top20, y=rf_feature_top20.index)
plt.show()
# Out:
# debt_settlement_flag_Y    0.209723
# sub_grade_num             0.173360
# int_rate                  0.142373
# total_rec_late_fee        0.115670
# term_ 60 months           0.075637
# total_rec_int             0.036231
# fico_range_mean           0.026774
# dti                       0.021619
# avg_cur_bal               0.016801
# grade_D                   0.015990
# loan_amnt                 0.015969
# installment               0.014609
# bc_open_to_buy            0.010988
# tot_cur_bal               0.010326
# annual_inc                0.009777
# acc_open_past_24mths      0.009692
# mort_acc                  0.007436
# open_rv_24m               0.007374
# total_bc_limit            0.005374
# mo_sin_old_rev_tl_op      0.004977
# dtype: float64

# %%
import dill
dill.dump_session('session_model_v5.db')  ## Save in the middle of the process

# %% [markdown]
# ### 3. GBM

# %% [markdown]
# #### * Before Tuning

# %%
start_time = time.time()

gb_clf = GradientBoostingClassifier(random_state=1)
gb_clf.fit(x_train, y_train)
gb_pred = gb_clf.predict(x_test)
gb_accuracy = accuracy_score(y_test, gb_pred)

print('gbm accuracy : {0:.4f}'.format(accuracy))
print('** accuracy (initial model) : ', 0.6685)
print('gbm running time : {0:.1f} seconds '.format(time.time()-start_time))
# Out:
# gbm accuracy : 0.6823
# ** accuracy (initial model) :  0.6685
# gbm running time : 41.8 seconds

# %% [markdown]
# #### * Hyper Parameter tuning

# %%
start_time = time.time()

gb2_clf = GradientBoostingClassifier(random_state=1)
gb_params = {
    'n_estimators': [100,300],
    'learning_rate': [0.05, 0.1],
     'max_depth': [1,3,6]
#     ,
#     'min_samples_leaf': [1,2,3],
#     'min_samples_split': [1,2,3]

}


gb_grid_cv = GridSearchCV(gb2_clf, param_grid=gb_params, cv=10, verbose=1)
gb_grid_cv.fit(x_train, y_train)

print('best parameter:\n', gb_grid_cv.best_params_)
print('best prediction accuracy: {0:.4f}'.format(gb_grid_cv.best_score_))
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed: 390.5min finished
# best parameter:
#  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 300}
# best prediction accuracy: 0.7388

# %%
### test with best param 
gb3_pred = gb_grid_cv.best_estimator_.predict(x_test)
gb3_accuracy = accuracy_score(y_test, gb3_pred)

print('GBM accuracy(After tuning) : {0:.4f}' .format(gb3_accuracy))
print('GBM tuning & running time : {0:.1f} seconds '.format(time.time()-start_time))
# Out:
# GBM accuracy(After tuning) : 0.7412
# GBM tuning & running time : 35753.8 seconds

# %%
gb_test_pred_prob = gb_grid_cv.predict_proba(x_test)
print('GBM ROC_AUC Score :', roc_auc_score(y_test, gb_test_pred_prob[:,1]))
# Out:
# GBM ROC_AUC Score : 0.8231270475636638

# %%
# calculate the fpr and tpr for all thresholds of the classification
GBM_test_pred_prob = gb_grid_cv.predict_proba(x_test)
GBM_preds = GBM_test_pred_prob[:,1]
GBM_fpr, GBM_tpr, GBM_threshold = metrics.roc_curve(y_test, GBM_preds)
GBM_roc_auc = metrics.auc(GBM_fpr, GBM_tpr)

# method I: plt
plt.title('GBM ROC')
plt.plot(GBM_fpr, GBM_tpr, 'b', label = 'AUC = %0.2f' % GBM_roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
gb_feature_imp = gb_grid_cv.best_estimator_.feature_importances_
gb_feature_imp = pd.Series(gb_feature_imp, index=x_train.columns)
gb_feature_top20 = gb_feature_imp.sort_values(ascending=False)[:20]
gb_feature_top40 = gb_feature_imp.sort_values(ascending=False)[:40]
print(gb_feature_top20)

plt.figure(figsize=(8,6))
plt.title('gb_Feature Importance (top20)')
sns.barplot(x=gb_feature_top20, y=gb_feature_top20.index)
plt.show()
# Out:
# sub_grade_num             0.256787
# debt_settlement_flag_Y    0.171217
# total_rec_int             0.131323
# total_rec_late_fee        0.068305
# installment               0.066723
# int_rate                  0.031949
# term_ 60 months           0.029109
# loan_amnt                 0.027991
# dti                       0.018157
# avg_cur_bal               0.017311
# annual_inc                0.016620
# mo_sin_old_rev_tl_op      0.010327
# num_rev_tl_bal_gt_0       0.009403
# revol_bal                 0.007833
# bc_open_to_buy            0.007489
# total_rev_hi_lim          0.007387
# fico_range_mean           0.007221
# revol_util                0.007073
# mo_sin_old_il_acct        0.006893
# total_acc                 0.006802
# dtype: float64

# %% [markdown]
# ### 4. XGBoost

# %%
start_time = time.time()

label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(y_train)
y_train_xgb = label_encoder.transform(y_train)

label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(y_test)
y_test_xgb = label_encoder.transform(y_test)

# %%
dtrain = xgb.DMatrix(data=x_train, label=y_train_xgb)
dtest = xgb.DMatrix(data=x_test, label=y_test_xgb)

# %%
xgb_params = {'max_depth':3, 'eta':0.1, 'objective':'binary:logistic', 'eval_metric':'logloss', 
              'early_stoppings':100}
num_rounds = 400

# %%
wlist = [(dtrain, 'train'), (dtest, 'eval')]
xgb_model = xgb.train(params = xgb_params, dtrain=dtrain, num_boost_round=num_rounds, evals=wlist)
# Out:
# [0]	train-logloss:0.676491	eval-logloss:0.67652
# [1]	train-logloss:0.66268	eval-logloss:0.662951
# [2]	train-logloss:0.650993	eval-logloss:0.651298
# [3]	train-logloss:0.641154	eval-logloss:0.641568
# [4]	train-logloss:0.632793	eval-logloss:0.633238
# [5]	train-logloss:0.625525	eval-logloss:0.626079
# [6]	train-logloss:0.619232	eval-logloss:0.619867
# [7]	train-logloss:0.613797	eval-logloss:0.614576
# [8]	train-logloss:0.609104	eval-logloss:0.609926
# [9]	train-logloss:0.604925	eval-logloss:0.605837
# [10]	train-logloss:0.60126	eval-logloss:0.602291
# [11]	train-logloss:0.598075	eval-logloss:0.599186
# [12]	train-logloss:0.595216	eval-logloss:0.596393
# [13]	train-logloss:0.592318	eval-logloss:0.593564
# [14]	train-logloss:0.589999	eval-logloss:0.59125
# [15]	train-logloss:0.587989	eval-logloss:0.589319
# [16]	train-logloss:0.586	eval-logloss:0.587374
# [17]	train-logloss:0.583892	eval-logloss:0.585371
# [18]	train-logloss:0.582324	eval-logloss:0.583885
# [19]	train-logloss:0.580833	eval-logloss:0.582405
# [20]	train-logloss:0.579259	eval-logloss:0.580915
# [21]	train-logloss:0.57787	eval-logloss:0.579532
# [22]	train-logloss:0.576627	eval-logloss:0.578303
# [23]	train-logloss:0.575355	eval-logloss:0.577153
# [24]	train-logloss:0.574219	eval-logloss:0.576019
# [25]	train-logloss:0.573184	eval-logloss:0.574972
# [26]	train-logloss:0.57222	eval-logloss:0.57398
# [27]	train-logloss:0.571035	eval-logloss:0.572939
# [28]	train-logloss:0.570186	eval-logloss:0.572151
# [29]	train-logloss:0.56928	eval-logloss:0.571259
# [30]	train-logloss:0.568446	eval-logloss:0.570488
# [31]	train-logloss:0.567468	eval-logloss:0.569583
# [32]	train-logloss:0.566765	eval-logloss:0.568933
# [33]	train-logloss:0.566119	eval-logloss:0.568292
# [34]	train-logloss:0.565416	eval-logloss:0.56754
# [35]	train-logloss:0.564758	eval-logloss:0.566986
# [36]	train-logloss:0.564149	eval-logloss:0.566386
# [37]	train-logloss:0.563343	eval-logloss:0.565559
# [38]	train-logloss:0.562799	eval-logloss:0.565025
# [39]	train-logloss:0.562214	eval-logloss:0.564426
# [40]	train-logloss:0.56138	eval-logloss:0.563617
# [41]	train-logloss:0.560844	eval-logloss:0.563186
# [42]	train-logloss:0.560376	eval-logloss:0.562724
# [43]	train-logloss:0.559881	eval-logloss:0.562217
# [44]	train-logloss:0.559063	eval-logloss:0.561456
# [45]	train-logloss:0.55831	eval-logloss:0.560724
# [46]	train-logloss:0.557414	eval-logloss:0.55995
# [47]	train-logloss:0.556958	eval-logloss:0.55954
# [48]	train-logloss:0.556287	eval-logloss:0.558929
# [49]	train-logloss:0.555887	eval-logloss:0.55851
# [50]	train-logloss:0.555203	eval-logloss:0.557834
# [51]	train-logloss:0.554744	eval-logloss:0.557385
# [52]	train-logloss:0.554166	eval-logloss:0.556882
# [53]	train-logloss:0.553821	eval-logloss:0.556571
# [54]	train-logloss:0.552929	eval-logloss:0.555742
# [55]	train-logloss:0.552297	eval-logloss:0.555194
# [56]	train-logloss:0.551832	eval-logloss:0.554826
# [57]	train-logloss:0.551458	eval-logloss:0.554419
# [58]	train-logloss:0.551157	eval-logloss:0.554138
# [59]	train-logloss:0.550703	eval-logloss:0.553719
# [60]	train-logloss:0.5502	eval-logloss:0.553252
# [61]	train-logloss:0.549667	eval-logloss:0.552734
# [62]	train-logloss:0.54933	eval-logloss:0.552395
# [63]	train-logloss:0.548765	eval-logloss:0.55179
# [64]	train-logloss:0.548186	eval-logloss:0.551266
# [65]	train-logloss:0.547749	eval-logloss:0.550893
# [66]	train-logloss:0.547393	eval-logloss:0.550542
# [67]	train-logloss:0.546884	eval-logloss:0.550102
# [68]	train-logloss:0.546577	eval-logloss:0.549809
# [69]	train-logloss:0.546317	eval-logloss:0.549534
# [70]	train-logloss:0.546023	eval-logloss:0.549299
# [71]	train-logloss:0.545675	eval-logloss:0.548951
# [72]	train-logloss:0.54541	eval-logloss:0.548693
# [73]	train-logloss:0.544751	eval-logloss:0.548022
# [74]	train-logloss:0.544283	eval-logloss:0.547625
# [75]	train-logloss:0.543973	eval-logloss:0.547312
# [76]	train-logloss:0.543766	eval-logloss:0.547131
# [77]	train-logloss:0.543534	eval-logloss:0.546887
# [78]	train-logloss:0.543054	eval-logloss:0.546443
# [79]	train-logloss:0.542489	eval-logloss:0.545894
# [80]	train-logloss:0.542077	eval-logloss:0.545498
# [81]	train-logloss:0.541886	eval-logloss:0.5453
# [82]	train-logloss:0.541437	eval-logloss:0.544906
# [83]	train-logloss:0.541143	eval-logloss:0.544594
# [84]	train-logloss:0.540907	eval-logloss:0.544336
# [85]	train-logloss:0.540641	eval-logloss:0.544099
# [86]	train-logloss:0.540465	eval-logloss:0.543953
# [87]	train-logloss:0.539758	eval-logloss:0.543339
# [88]	train-logloss:0.539414	eval-logloss:0.543091
# [89]	train-logloss:0.539044	eval-logloss:0.542755
# [90]	train-logloss:0.538799	eval-logloss:0.542504
# [91]	train-logloss:0.538589	eval-logloss:0.542353
# [92]	train-logloss:0.538413	eval-logloss:0.542175
# [93]	train-logloss:0.5382	eval-logloss:0.54195
# [94]	train-logloss:0.537861	eval-logloss:0.541624
# [95]	train-logloss:0.537632	eval-logloss:0.54139
# [96]	train-logloss:0.537365	eval-logloss:0.541151
# [97]	train-logloss:0.537209	eval-logloss:0.540984
# [98]	train-logloss:0.537034	eval-logloss:0.540838
# [99]	train-logloss:0.536699	eval-logloss:0.540566
# [100]	train-logloss:0.536472	eval-logloss:0.540366
# [101]	train-logloss:0.53629	eval-logloss:0.540184
# [102]	train-logloss:0.536151	eval-logloss:0.540057
# [103]	train-logloss:0.535922	eval-logloss:0.539845
# [104]	train-logloss:0.535794	eval-logloss:0.539737
# [105]	train-logloss:0.535559	eval-logloss:0.539518
# [106]	train-logloss:0.534998	eval-logloss:0.53902
# [107]	train-logloss:0.534703	eval-logloss:0.538731
# [108]	train-logloss:0.534436	eval-logloss:0.538525
# [109]	train-logloss:0.534063	eval-logloss:0.538203
# [110]	train-logloss:0.533838	eval-logloss:0.537992
# [111]	train-logloss:0.533716	eval-logloss:0.537854
# [112]	train-logloss:0.53357	eval-logloss:0.537726
# [113]	train-logloss:0.533321	eval-logloss:0.537498
# [114]	train-logloss:0.533169	eval-logloss:0.537384
# [115]	train-logloss:0.532866	eval-logloss:0.537101
# [116]	train-logloss:0.532586	eval-logloss:0.536886
# [117]	train-logloss:0.532435	eval-logloss:0.536783
# [118]	train-logloss:0.532181	eval-logloss:0.536544
# [119]	train-logloss:0.532041	eval-logloss:0.536419
# [120]	train-logloss:0.531945	eval-logloss:0.536308
# [121]	train-logloss:0.531801	eval-logloss:0.536152
# [122]	train-logloss:0.531531	eval-logloss:0.53592
# [123]	train-logloss:0.531312	eval-logloss:0.535725
# [124]	train-logloss:0.531152	eval-logloss:0.535606
# [125]	train-logloss:0.531001	eval-logloss:0.535481
# [126]	train-logloss:0.530777	eval-logloss:0.535321
# [127]	train-logloss:0.530668	eval-logloss:0.535223
# [128]	train-logloss:0.530575	eval-logloss:0.535122
# [129]	train-logloss:0.530309	eval-logloss:0.534874
# [130]	train-logloss:0.529911	eval-logloss:0.534496
# [131]	train-logloss:0.529782	eval-logloss:0.534378
# [132]	train-logloss:0.529644	eval-logloss:0.534251
# [133]	train-logloss:0.529516	eval-logloss:0.534119
# [134]	train-logloss:0.529062	eval-logloss:0.533636
# [135]	train-logloss:0.528946	eval-logloss:0.533511
# [136]	train-logloss:0.528863	eval-logloss:0.533417
# [137]	train-logloss:0.528744	eval-logloss:0.53336
# [138]	train-logloss:0.528443	eval-logloss:0.533046
# [139]	train-logloss:0.528182	eval-logloss:0.532842
# [140]	train-logloss:0.528034	eval-logloss:0.5327
# [141]	train-logloss:0.527598	eval-logloss:0.532288
# [142]	train-logloss:0.527415	eval-logloss:0.532128
# [143]	train-logloss:0.527251	eval-logloss:0.531996
# [144]	train-logloss:0.527076	eval-logloss:0.531839
# [145]	train-logloss:0.526926	eval-logloss:0.531704
# [146]	train-logloss:0.526811	eval-logloss:0.531633
# [147]	train-logloss:0.526731	eval-logloss:0.531558
# [148]	train-logloss:0.526658	eval-logloss:0.53149
# [149]	train-logloss:0.526542	eval-logloss:0.531401
# [150]	train-logloss:0.526447	eval-logloss:0.531324
# [151]	train-logloss:0.526321	eval-logloss:0.531202
# [152]	train-logloss:0.526208	eval-logloss:0.531116
# [153]	train-logloss:0.526022	eval-logloss:0.530892
# [154]	train-logloss:0.525835	eval-logloss:0.530729
# [155]	train-logloss:0.525741	eval-logloss:0.530671
# [156]	train-logloss:0.525675	eval-logloss:0.530606
# [157]	train-logloss:0.525581	eval-logloss:0.530499
# [158]	train-logloss:0.525473	eval-logloss:0.530387
# [159]	train-logloss:0.525334	eval-logloss:0.530292
# [160]	train-logloss:0.525249	eval-logloss:0.530222
# [161]	train-logloss:0.525004	eval-logloss:0.530005
# [162]	train-logloss:0.524918	eval-logloss:0.529917
# [163]	train-logloss:0.52486	eval-logloss:0.529866
# [164]	train-logloss:0.524745	eval-logloss:0.52977
# [165]	train-logloss:0.524649	eval-logloss:0.529689
# [166]	train-logloss:0.524475	eval-logloss:0.529539
# [167]	train-logloss:0.524343	eval-logloss:0.529392
# [168]	train-logloss:0.524153	eval-logloss:0.529216
# [169]	train-logloss:0.523929	eval-logloss:0.529041
# [170]	train-logloss:0.523875	eval-logloss:0.528991
# [171]	train-logloss:0.523794	eval-logloss:0.528922
# [172]	train-logloss:0.523692	eval-logloss:0.52883
# [173]	train-logloss:0.52357	eval-logloss:0.528727
# [174]	train-logloss:0.523316	eval-logloss:0.528467
# [175]	train-logloss:0.523	eval-logloss:0.528172
# [176]	train-logloss:0.522866	eval-logloss:0.528055
# [177]	train-logloss:0.522771	eval-logloss:0.527979
# [178]	train-logloss:0.522654	eval-logloss:0.527884
# [179]	train-logloss:0.522559	eval-logloss:0.527839
# [180]	train-logloss:0.522386	eval-logloss:0.527682
# [181]	train-logloss:0.522296	eval-logloss:0.527633
# [182]	train-logloss:0.522246	eval-logloss:0.527583
# [183]	train-logloss:0.522196	eval-logloss:0.52754
# [184]	train-logloss:0.521976	eval-logloss:0.527365
# [185]	train-logloss:0.521893	eval-logloss:0.527302
# [186]	train-logloss:0.521817	eval-logloss:0.527248
# [187]	train-logloss:0.521744	eval-logloss:0.527196
# [188]	train-logloss:0.521652	eval-logloss:0.527099
# [189]	train-logloss:0.521523	eval-logloss:0.526997
# [190]	train-logloss:0.521468	eval-logloss:0.526947
# [191]	train-logloss:0.521176	eval-logloss:0.526654
# [192]	train-logloss:0.521085	eval-logloss:0.526579
# [193]	train-logloss:0.520961	eval-logloss:0.526491
# [194]	train-logloss:0.520899	eval-logloss:0.526447
# [195]	train-logloss:0.52084	eval-logloss:0.526405
# [196]	train-logloss:0.52075	eval-logloss:0.526369
# [197]	train-logloss:0.52066	eval-logloss:0.526309
# [198]	train-logloss:0.520464	eval-logloss:0.526147
# [199]	train-logloss:0.520423	eval-logloss:0.526115
# [200]	train-logloss:0.520356	eval-logloss:0.526078
# [201]	train-logloss:0.520242	eval-logloss:0.525978
# [202]	train-logloss:0.520163	eval-logloss:0.525948
# [203]	train-logloss:0.520078	eval-logloss:0.525869
# [204]	train-logloss:0.520008	eval-logloss:0.525809
# [205]	train-logloss:0.519937	eval-logloss:0.525749
# [206]	train-logloss:0.519869	eval-logloss:0.52571
# [207]	train-logloss:0.519798	eval-logloss:0.525691
# [208]	train-logloss:0.519735	eval-logloss:0.525664
# [209]	train-logloss:0.519481	eval-logloss:0.525418
# [210]	train-logloss:0.519431	eval-logloss:0.525359
# [211]	train-logloss:0.519393	eval-logloss:0.525338
# [212]	train-logloss:0.519315	eval-logloss:0.525273
# [213]	train-logloss:0.519132	eval-logloss:0.525124
# [214]	train-logloss:0.518814	eval-logloss:0.524901
# [215]	train-logloss:0.518661	eval-logloss:0.524778
# [216]	train-logloss:0.51857	eval-logloss:0.524709
# [217]	train-logloss:0.518517	eval-logloss:0.524646
# [218]	train-logloss:0.518438	eval-logloss:0.524591
# [219]	train-logloss:0.51838	eval-logloss:0.524547
# [220]	train-logloss:0.518337	eval-logloss:0.524522
# [221]	train-logloss:0.51817	eval-logloss:0.524387
# [222]	train-logloss:0.518078	eval-logloss:0.524306
# [223]	train-logloss:0.517873	eval-logloss:0.524124
# [224]	train-logloss:0.517816	eval-logloss:0.524064
# [225]	train-logloss:0.517734	eval-logloss:0.524006
# [226]	train-logloss:0.517632	eval-logloss:0.52392
# [227]	train-logloss:0.517581	eval-logloss:0.523894
# [228]	train-logloss:0.517328	eval-logloss:0.523711
# [229]	train-logloss:0.517129	eval-logloss:0.523557
# [230]	train-logloss:0.516966	eval-logloss:0.523386
# [231]	train-logloss:0.516897	eval-logloss:0.523352
# [232]	train-logloss:0.516839	eval-logloss:0.523321
# [233]	train-logloss:0.516684	eval-logloss:0.523202
# [234]	train-logloss:0.516569	eval-logloss:0.523106
# [235]	train-logloss:0.516473	eval-logloss:0.523058
# [236]	train-logloss:0.5164	eval-logloss:0.522998
# [237]	train-logloss:0.516338	eval-logloss:0.522974
# [238]	train-logloss:0.51626	eval-logloss:0.52293
# [239]	train-logloss:0.516204	eval-logloss:0.522909
# [240]	train-logloss:0.516172	eval-logloss:0.522882
# [241]	train-logloss:0.516123	eval-logloss:0.522868
# [242]	train-logloss:0.516063	eval-logloss:0.522834
# [243]	train-logloss:0.51603	eval-logloss:0.52281
# [244]	train-logloss:0.515933	eval-logloss:0.522735
# [245]	train-logloss:0.515852	eval-logloss:0.522666
# [246]	train-logloss:0.515794	eval-logloss:0.522587
# [247]	train-logloss:0.515638	eval-logloss:0.522455
# [248]	train-logloss:0.515538	eval-logloss:0.522367
# [249]	train-logloss:0.515507	eval-logloss:0.522355
# [250]	train-logloss:0.51547	eval-logloss:0.52234
# [251]	train-logloss:0.515407	eval-logloss:0.522301
# [252]	train-logloss:0.515333	eval-logloss:0.522247
# [253]	train-logloss:0.515268	eval-logloss:0.522211
# [254]	train-logloss:0.515154	eval-logloss:0.522098
# [255]	train-logloss:0.514988	eval-logloss:0.521925
# [256]	train-logloss:0.514927	eval-logloss:0.521902
# [257]	train-logloss:0.514871	eval-logloss:0.52187
# [258]	train-logloss:0.514786	eval-logloss:0.521818
# [259]	train-logloss:0.514747	eval-logloss:0.521798
# [260]	train-logloss:0.514683	eval-logloss:0.52177
# [261]	train-logloss:0.514656	eval-logloss:0.521751
# [262]	train-logloss:0.514585	eval-logloss:0.521698
# [263]	train-logloss:0.514431	eval-logloss:0.521569
# [264]	train-logloss:0.51438	eval-logloss:0.521537
# [265]	train-logloss:0.514314	eval-logloss:0.5215
# [266]	train-logloss:0.514199	eval-logloss:0.521406
# [267]	train-logloss:0.514135	eval-logloss:0.521367
# [268]	train-logloss:0.51408	eval-logloss:0.521358
# [269]	train-logloss:0.514013	eval-logloss:0.5213
# [270]	train-logloss:0.513967	eval-logloss:0.521287
# [271]	train-logloss:0.513738	eval-logloss:0.521122
# [272]	train-logloss:0.513569	eval-logloss:0.520969
# [273]	train-logloss:0.513497	eval-logloss:0.520902
# [274]	train-logloss:0.513459	eval-logloss:0.52087
# [275]	train-logloss:0.513433	eval-logloss:0.520857
# [276]	train-logloss:0.51332	eval-logloss:0.520753
# [277]	train-logloss:0.513264	eval-logloss:0.520701
# [278]	train-logloss:0.513232	eval-logloss:0.520667
# [279]	train-logloss:0.51319	eval-logloss:0.520634
# [280]	train-logloss:0.513146	eval-logloss:0.520611
# [281]	train-logloss:0.513101	eval-logloss:0.52057
# [282]	train-logloss:0.513027	eval-logloss:0.520507
# [283]	train-logloss:0.512987	eval-logloss:0.520496
# [284]	train-logloss:0.512956	eval-logloss:0.520471
# [285]	train-logloss:0.512901	eval-logloss:0.520459
# [286]	train-logloss:0.512876	eval-logloss:0.520451
# [287]	train-logloss:0.512822	eval-logloss:0.520423
# [288]	train-logloss:0.512781	eval-logloss:0.520411
# [289]	train-logloss:0.512723	eval-logloss:0.520396
# [290]	train-logloss:0.512661	eval-logloss:0.520365
# [291]	train-logloss:0.512597	eval-logloss:0.52031
# [292]	train-logloss:0.512541	eval-logloss:0.520276
# [293]	train-logloss:0.512505	eval-logloss:0.520259
# [294]	train-logloss:0.512348	eval-logloss:0.520114
# [295]	train-logloss:0.512226	eval-logloss:0.519992
# [296]	train-logloss:0.512172	eval-logloss:0.519973
# [297]	train-logloss:0.512119	eval-logloss:0.519948
# [298]	train-logloss:0.512062	eval-logloss:0.519911
# [299]	train-logloss:0.511985	eval-logloss:0.519828
# [300]	train-logloss:0.511852	eval-logloss:0.519734
# [301]	train-logloss:0.511686	eval-logloss:0.519565
# [302]	train-logloss:0.51164	eval-logloss:0.519553
# [303]	train-logloss:0.511592	eval-logloss:0.519522
# [304]	train-logloss:0.511554	eval-logloss:0.51951
# [305]	train-logloss:0.511359	eval-logloss:0.519353
# [306]	train-logloss:0.511326	eval-logloss:0.519334
# [307]	train-logloss:0.5113	eval-logloss:0.519304
# [308]	train-logloss:0.511264	eval-logloss:0.519298
# [309]	train-logloss:0.511225	eval-logloss:0.519275
# [310]	train-logloss:0.511205	eval-logloss:0.519268
# [311]	train-logloss:0.511162	eval-logloss:0.519243
# [312]	train-logloss:0.51113	eval-logloss:0.519229
# [313]	train-logloss:0.511044	eval-logloss:0.519178
# [314]	train-logloss:0.511007	eval-logloss:0.519159
# [315]	train-logloss:0.51096	eval-logloss:0.51914
# [316]	train-logloss:0.510896	eval-logloss:0.519082
# [317]	train-logloss:0.510745	eval-logloss:0.518947
# [318]	train-logloss:0.510717	eval-logloss:0.518927
# [319]	train-logloss:0.510582	eval-logloss:0.518808
# [320]	train-logloss:0.510468	eval-logloss:0.518697
# [321]	train-logloss:0.510403	eval-logloss:0.518653
# [322]	train-logloss:0.510298	eval-logloss:0.518562
# [323]	train-logloss:0.510246	eval-logloss:0.518538
# [324]	train-logloss:0.510206	eval-logloss:0.518511
# [325]	train-logloss:0.510161	eval-logloss:0.518474
# [326]	train-logloss:0.510113	eval-logloss:0.518432
# [327]	train-logloss:0.51001	eval-logloss:0.518351
# [328]	train-logloss:0.509989	eval-logloss:0.518345
# [329]	train-logloss:0.509948	eval-logloss:0.518338
# [330]	train-logloss:0.509887	eval-logloss:0.5183
# [331]	train-logloss:0.50984	eval-logloss:0.518259
# [332]	train-logloss:0.509791	eval-logloss:0.518248
# [333]	train-logloss:0.509736	eval-logloss:0.518202
# [334]	train-logloss:0.509703	eval-logloss:0.518185
# [335]	train-logloss:0.509582	eval-logloss:0.518091
# [336]	train-logloss:0.509498	eval-logloss:0.518031
# [337]	train-logloss:0.509447	eval-logloss:0.517987
# [338]	train-logloss:0.50941	eval-logloss:0.517985
# [339]	train-logloss:0.50937	eval-logloss:0.517957
# [340]	train-logloss:0.509339	eval-logloss:0.517945
# [341]	train-logloss:0.509306	eval-logloss:0.517933
# [342]	train-logloss:0.509273	eval-logloss:0.517924
# [343]	train-logloss:0.50924	eval-logloss:0.517935
# [344]	train-logloss:0.509199	eval-logloss:0.517918
# [345]	train-logloss:0.509036	eval-logloss:0.517794
# [346]	train-logloss:0.509004	eval-logloss:0.517791
# [347]	train-logloss:0.508936	eval-logloss:0.517734
# [348]	train-logloss:0.508908	eval-logloss:0.517706
# [349]	train-logloss:0.508863	eval-logloss:0.517696
# [350]	train-logloss:0.508816	eval-logloss:0.517673
# [351]	train-logloss:0.50878	eval-logloss:0.517677
# [352]	train-logloss:0.508736	eval-logloss:0.517663
# [353]	train-logloss:0.508588	eval-logloss:0.517526
# [354]	train-logloss:0.508443	eval-logloss:0.517394
# [355]	train-logloss:0.508391	eval-logloss:0.517369
# [356]	train-logloss:0.508352	eval-logloss:0.517341
# [357]	train-logloss:0.508334	eval-logloss:0.517329
# [358]	train-logloss:0.508317	eval-logloss:0.51732
# [359]	train-logloss:0.50828	eval-logloss:0.517312
# [360]	train-logloss:0.508251	eval-logloss:0.517292
# [361]	train-logloss:0.508222	eval-logloss:0.51729
# [362]	train-logloss:0.508184	eval-logloss:0.517274
# [363]	train-logloss:0.508137	eval-logloss:0.517262
# [364]	train-logloss:0.508085	eval-logloss:0.517238
# [365]	train-logloss:0.508036	eval-logloss:0.517216
# [366]	train-logloss:0.507977	eval-logloss:0.517209
# [367]	train-logloss:0.507931	eval-logloss:0.517181
# [368]	train-logloss:0.507873	eval-logloss:0.517139
# [369]	train-logloss:0.507851	eval-logloss:0.517125
# [370]	train-logloss:0.507835	eval-logloss:0.517118
# [371]	train-logloss:0.507806	eval-logloss:0.517101
# [372]	train-logloss:0.507764	eval-logloss:0.517095
# [373]	train-logloss:0.50773	eval-logloss:0.51708
# [374]	train-logloss:0.507606	eval-logloss:0.516958
# [375]	train-logloss:0.507526	eval-logloss:0.516928
# [376]	train-logloss:0.507482	eval-logloss:0.516912
# [377]	train-logloss:0.507439	eval-logloss:0.516868
# [378]	train-logloss:0.507405	eval-logloss:0.516855
# [379]	train-logloss:0.507357	eval-logloss:0.51683
# [380]	train-logloss:0.5073	eval-logloss:0.516781
# [381]	train-logloss:0.507271	eval-logloss:0.516758
# [382]	train-logloss:0.507245	eval-logloss:0.51674
# [383]	train-logloss:0.507211	eval-logloss:0.516728
# [384]	train-logloss:0.507175	eval-logloss:0.516707
# [385]	train-logloss:0.507146	eval-logloss:0.516711
# [386]	train-logloss:0.50713	eval-logloss:0.516698
# [387]	train-logloss:0.507004	eval-logloss:0.516543
# [388]	train-logloss:0.506916	eval-logloss:0.516464
# [389]	train-logloss:0.506852	eval-logloss:0.516396
# [390]	train-logloss:0.506819	eval-logloss:0.516359
# [391]	train-logloss:0.506772	eval-logloss:0.516346
# [392]	train-logloss:0.506738	eval-logloss:0.516318
# [393]	train-logloss:0.506709	eval-logloss:0.516317
# [394]	train-logloss:0.506649	eval-logloss:0.516267
# [395]	train-logloss:0.506615	eval-logloss:0.516266
# [396]	train-logloss:0.50658	eval-logloss:0.516265
# [397]	train-logloss:0.506564	eval-logloss:0.516255
# [398]	train-logloss:0.506543	eval-logloss:0.516246
# [399]	train-logloss:0.506476	eval-logloss:0.51619

# %%
pred_probs = xgb_model.predict(dtest)
xgb_preds = [1 if x>0.5 else 0 for x in pred_probs]

# %%
def get_clf_eval(y_test, pred):
    confusion = confusion_matrix(y_test_xgb, pred)
    accuracy = accuracy_score(y_test_xgb , pred)
    precision = precision_score(y_test_xgb , pred)
    recall = recall_score(y_test_xgb , pred)
    print('confusion matrix')
    print(confusion)
    print('XGBoost Accuracy: {0:.4f}, Precision: {1:.4f}, Recall: {2:.4f}'.format(accuracy , precision ,recall))

# %%
get_clf_eval(y_test_xgb, xgb_preds)
print('** accuracy (initial model) : ', 'Accuracy: 0.7345, Precision: 0.7293, Recall: 0.8045')
print('XGBoost running time : {0:.1f} seconds '.format(time.time()-start_time))
# Out:
# confusion matrix
# [[12152  6449]
#  [ 4122 17273]]
# XGBoost Accuracy: 0.7357, Precision: 0.7281, Recall: 0.8073
# ** accuracy (initial model) :  Accuracy: 0.7345, Precision: 0.7293, Recall: 0.8045
# XGBoost running time : 52.7 seconds

# %%
xgb_model.get_score(importance_type='weight')
# Out:
# {'sub_grade_num': 63,
#  'debt_settlement_flag_Y': 88,
#  'total_rec_late_fee': 97,
#  'term_ 60 months': 84,
#  'int_rate': 147,
#  'total_rec_int': 557,
#  'avg_cur_bal': 53,
#  'loan_amnt': 194,
#  'dti': 61,
#  'tot_cur_bal': 26,
#  'home_ownership_RENT': 19,
#  'acc_open_past_24mths': 28,
#  'installment': 245,
#  'fico_range_mean': 27,
#  'mort_acc': 16,
#  'open_rv_24m': 13,
#  'il_util': 37,
#  'num_rev_tl_bal_gt_0': 70,
#  'inq_last_6mths': 28,
#  'purpose_small_business': 19,
#  'max_bal_bc': 43,
#  'all_util': 35,
#  'annual_inc': 79,
#  'revol_util': 28,
#  'mo_sin_old_rev_tl_op': 82,
#  'mths_since_recent_inq': 27,
#  'home_ownership_MORTGAGE': 3,
#  'bc_open_to_buy': 39,
#  'revol_bal': 41,
#  'open_acc_6m': 19,
#  'total_rev_hi_lim': 53,
#  'mths_since_recent_bc': 38,
#  'total_bc_limit': 25,
#  'total_acc': 56,
#  'total_bal_il': 26,
#  'mo_sin_old_il_acct': 46,
#  'percent_bc_gt_75': 19,
#  'verification_status_Verified': 9,
#  'mths_since_last_delinq': 46,
#  'bc_util': 26,
#  'mths_since_rcnt_il': 31,
#  'grade_D': 3}

# %%
fig, ax = plt.subplots(figsize=(12,18))
xgb.plot_importance(xgb_model, max_num_features=50, height=0.8, ax=ax)
plt.title('XGB_Feature Importance (top50)')
plt.show()

# %% [markdown]
# ### 5. SVM (SVC)

# %%
start_time = time.time()

n_estimators = 10
svm_clf = LinearSVC(random_state=1)
svm_clf.fit(x_train, y_train)
svm_pred = svm_clf.predict(x_test)

print('SVM train score : {0:.1f} seconds ', svm_clf.score(x_train, y_train))
print('SVM pred test score : {0:.1f} seconds ', svm_clf.score(x_test, y_test))
# Out:
# SVM train score : {0:.1f} seconds  0.46046767469043587
# SVM pred test score : {0:.1f} seconds  0.46507150715071505

# %% [markdown]
# #### * Hyper Parameter tuning

# %%
start_time = time.time()

svm2_clf = LinearSVC(random_state=1)
svm_params = {'C': [1, 10, 100, 1000]}

# GridSearchCV
svm_grid_cv = GridSearchCV(svm2_clf, param_grid=svm_params, cv=5)
svm_grid_cv.fit(x_train,y_train)
svm2_pred = svm_grid_cv.predict(x_test)

print('SVM best parameter:\n', svm_grid_cv.best_params_)
print('SVM best prediction accuracy: {0:.4f}'.format(svm_grid_cv.best_score_))
print('SVM best prediction for test accuracy: {0:.4f}' .format(accuracy_score(y_test, svm2_pred)))
print('SVM tuning & running time : {0:.1f} seconds '.format(time.time()-start_time))
# Out:
# SVM best parameter:
#  {'C': 1}
# SVM best prediction accuracy: 0.5501
# SVM best prediction for test accuracy: 0.4651
# SVM tuning & running time : 1009.5 seconds

# %%
# svm_test_pred_prob = svm_grid_cv.predict_proba(x_test)
# print('SVM ROC_AUC Score :', roc_auc_score(y_test, svm_test_pred_prob[:,1]))

# %%
# %matplotlib inline

svm_feature_imp = pd.DataFrame(svm_grid_cv.best_estimator_.coef_, columns=x_train.columns).transpose()
svm_feature_imp['abs']=svm_feature_imp[0].apply(np.abs).round(6)
svm_feature_top20 = svm_feature_imp.sort_values(by= ['abs'], ascending=False)[:20]
svm_feature_top40 = svm_feature_imp.sort_values(by= ['abs'], ascending=False)[:40]

print(svm_feature_top20)

plt.figure(figsize=(8,6))
plt.title('SVM Feature Importance (top20)')
sns.barplot(x=svm_feature_top20['abs'], y=svm_feature_top20.index)
plt.show()
# Out:
#                                0       abs
# sub_grade_num          -0.018422  0.018422
# int_rate               -0.013600  0.013600
# total_rec_late_fee     -0.013378  0.013378
# dti                    -0.005744  0.005744
# mths_since_recent_inq   0.005489  0.005489
# acc_open_past_24mths   -0.004423  0.004423
# open_rv_24m            -0.003220  0.003220
# num_rev_tl_bal_gt_0    -0.002266  0.002266
# installment             0.001725  0.001725
# open_acc_6m            -0.001373  0.001373
# il_util                -0.001247  0.001247
# debt_settlement_flag_Y -0.001220  0.001220
# mths_since_rcnt_il     -0.001052  0.001052
# mths_since_recent_bc    0.001033  0.001033
# percent_bc_gt_75       -0.000992  0.000992
# inq_last_6mths         -0.000967  0.000967
# fico_range_mean         0.000903  0.000903
# mths_since_last_delinq  0.000819  0.000819
# all_util               -0.000784  0.000784
# mort_acc                0.000784  0.000784

# %% [markdown]
# ### 6. naive_bayes (GaussianNB)

# %%
start_time = time.time()

gnb_clf = GaussianNB()
gnb_clf.fit(x_train, y_train)
gnb_pred = gnb_clf.predict(x_test)

# Evaluate accuracy
print('naive_bayes prediction accuracy: : {0:.4f}', accuracy_score(y_test, gnb_pred))
print('Naive_bayes running time : {0:.1f} seconds '.format(time.time()-start_time))
# Out:
# naive_bayes prediction accuracy: : {0:.4f} 0.6181618161816181
# Naive_bayes running time : 0.2 seconds

# %% [markdown]
# ### 7. Neural Net (Simple ver.)

# %%
start_time = time.time()

NN_clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)
NN_clf.fit(x_train, y_train)
NN_clf_pred = NN_clf.predict(x_test)

# Evaluate accuracy
print('NN Score prediction accuracy: : {0:.4f}',round(NN_clf.score(x_train,y_train), 4))
print('NN test prediction accuracy: : {0:.4f}', accuracy_score(y_test, NN_clf_pred))
print('Neural Net running time : {0:.1f} seconds '.format(time.time()-start_time))
# Out:
# NN Score prediction accuracy: : {0:.4f} 0.5396
# NN test prediction accuracy: : {0:.4f} 0.5349284928492849
# Neural Net running time : 0.2 seconds

# %% [markdown]
# #### * Hyper Parameter tuning

# %%
start_time = time.time()

NN2_clf = MLPClassifier(max_iter=100)
NN2_params = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive']
}

NN2_grid_cv = GridSearchCV(NN2_clf, param_grid=NN2_params, cv=5)
NN2_grid_cv.fit(x_train,y_train)
NN2_pred = NN2_grid_cv.predict(x_test)

print('Neural Net best parameter:\n', NN2_grid_cv.best_params_)
print('Neural Net best prediction accuracy: {0:.4f}'.format(NN2_grid_cv.best_score_))
print('Neural Net best prediction (test accuracy) : {0:.4f}' .format(accuracy_score(y_test, NN2_pred)))
print('Neural Net  tuning & running time : {0:.1f} seconds '.format(time.time()-start_time))
# Out:
# Neural Net best parameter:
#  {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# Neural Net best prediction accuracy: 0.6052
# Neural Net best prediction (test accuracy) : 0.6294
# Neural Net  tuning & running time : 8661.0 seconds

# %%
nn_test_pred_prob = NN2_grid_cv.predict_proba(x_test)
print('NN ROC_AUC Score :', roc_auc_score(y_test, nn_test_pred_prob[:,1]))
# Out:
# NN ROC_AUC Score : 0.7149606892778508

# %%
# calculate the fpr and tpr for all thresholds of the classification
NN_test_pred_prob = NN2_grid_cv.predict_proba(x_test)
NN_preds = NN_test_pred_prob[:,1]
NN_fpr, NN_tpr, NN_threshold = metrics.roc_curve(y_test, NN_preds)
NN_roc_auc = metrics.auc(NN_fpr, NN_tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Neural Net ROC')
plt.plot(NN_fpr, NN_tpr, 'b', label = 'AUC = %0.2f' % NN_roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# %matplotlib inline

# nn_feature_imp = NN2_grid_cv.best_estimator_.coefs_
# nn_feature_imp = pd.Series(NN2_grid_cv, index=x_train.columns)
# nn_feature_top20 = nn_feature_imp.sort_values(ascending=False)[:20]
# nn_feature_top40_svm = nn_feature_imp.sort_values(ascending=False)[:40]

# print(feature_top20)

# plt.figure(figsize=(8,6))
# plt.title('NN Feature Importance (top20)')
# sns.barplot(x=nn_feature_top20, y=nn_feature_top20.index)
# plt.show()

# %%
print('RF\n', feature_top40_rf,'\n')
print('GBM\n', gb_feature_top40,'\n')
print('XGB\n', xgb_model.get_score(importance_type='weight'), '\n')
print('SVM', svm_feature_top40,'\n')
# print('NN\n', NN_feature_imp_top40,'\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-4e62e4a6bf38> in <module>
# ----> 1 print('RF\n', feature_top40_rf,'\n')
#       2 print('GBM\n', gb_feature_top40,'\n')
#       3 print('XGB\n', xgb_model.get_score(importance_type='weight'), '\n')
#       4 print('SVM', svm_feature_top40,'\n')
#       5 # print('NN\n', NN_feature_imp_top40,'\n')
#
# NameError: name 'feature_top40_rf' is not defined

# %%
print('logistic regression accuracy : %.2f' % accuracy_score(y_test, lr_pred))
print('rf3 accuracy : {0:.4f}' .format(accuracy_score(y_test, rf3_pred)))
print('GBM accuracy(After tuning) : {0:.4f}' .format(gb3_accuracy))
get_clf_eval(y_test_xgb, xgb_preds)
print('SVM best prediction accuracy: {0:.4f}'.format(svm_grid_cv.best_score_))
print('SVM best prediction for test accuracy: : {0:.4f}' .format(accuracy_score(y_test, svm2_pred)))
print('naive_bayes prediction accuracy: : {0:.4f}', accuracy_score(y_test, gnb_pred))
#print('NN Score prediction accuracy: : {0:.4f}',round(NN_clf.score(x_train,y), 4))
print('NN test prediction accuracy: : {0:.4f}', accuracy_score(y_test, NN2_pred))

# %%
import dill
dill.dump_session('session_model_v6_2.db')  ## Save

# import dill
# dill.load_session('session_model_v4.db')  ## Restore
