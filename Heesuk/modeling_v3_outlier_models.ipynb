# %% [markdown]
# ## Model Version 3

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import sklearn 
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from xgboost import plot_importance
import time
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

# %%
df = pd.read_csv("final.df.csv")
df.shape
# Out:
# (200000, 80)

# %%
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 200)
df.describe()
# need to check (distribution extreme.. check after initial modeling) :  
#    dti, total_rec_late_fee, recoveries, tot_coll_amt, mths_since_rcnt_il, il_util, max_bal_bc, avg_cur_bal,
#    delinq_amnt, mo_sin_rcnt_rev_tl_op, mo_sin_rcnt_tl, mths_since_recent_revol_delinq, tax_liens
# Out:
#            loan_amnt       int_rate    installment    annual_inc            dti    delinq_2yrs  inq_last_6mths  mths_since_last_delinq       open_acc        pub_rec     revol_bal     revol_util  \
# count  200000.000000  200000.000000  200000.000000  2.000000e+05  200000.000000  200000.000000   200000.000000           200000.000000  200000.000000  200000.000000  2.000000e+05  200000.000000
# mean    14740.615375      14.047924     445.564543  7.432490e+04      18.931042       0.326485        0.694805               38.589950      11.683355       0.226445  1.590229e+04      52.740852
# std      8752.102580       4.954058     262.118049  7.020791e+04      11.675555       0.886051        0.964933               21.663606       5.529451       0.631672  2.076584e+04      24.399791
# min       500.000000       5.310000      14.010000  0.000000e+00      -1.000000       0.000000        0.000000                0.000000       0.000000       0.000000  0.000000e+00       0.000000
# 25%      8000.000000      10.640000     257.200000  4.500000e+04      12.350000       0.000000        0.000000               22.000000       8.000000       0.000000  5.936000e+03      34.600000
# 50%     12625.000000      13.490000     382.360000  6.300000e+04      18.330000       0.000000        0.000000               36.000000      11.000000       0.000000  1.108700e+04      53.300000
# 75%     20000.000000      16.990000     587.550000  9.000000e+04      24.830000       0.000000        1.000000               55.000000      14.000000       0.000000  1.940200e+04      71.600000
# max     40000.000000      30.990000    1717.630000  1.099920e+07     999.000000      21.000000        8.000000              202.000000      80.000000      86.000000  1.190046e+06     182.800000
#
#            total_acc    total_pymnt  total_rec_int  total_rec_late_fee     recoveries  last_pymnt_amnt  last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  acc_now_delinq  \
# count  200000.000000  200000.000000  200000.000000       200000.000000  200000.000000    200000.000000         200000.000000        200000.000000               200000.000000   200000.000000
# mean       24.888360   12636.221310    2478.097381            2.624044     560.785900      3799.395097            641.761105           610.148025                    0.018800        0.005245
# std        12.065927    9763.746055    2626.966900           13.561922    1410.832467      6281.502295             89.661439           169.790827                    0.152829        0.079168
# min         2.000000       0.000000       0.000000            0.000000       0.000000         0.000000              0.000000             0.000000                    0.000000        0.000000
# 25%        16.000000    5411.899123     786.697500            0.000000       0.000000       318.790000            564.000000           560.000000                    0.000000        0.000000
# 50%        23.000000   10080.124295    1632.645000            0.000000       0.000000       652.410000            649.000000           645.000000                    0.000000        0.000000
# 75%        32.000000   17291.974973    3179.242500            0.000000     449.050000      4799.417500            714.000000           710.000000                    0.000000        0.000000
# max       173.000000   62687.030890   27687.030000         1188.830000   37153.460000     41096.620000            850.000000           845.000000                    9.000000        6.000000
#
#         tot_coll_amt   tot_cur_bal    open_acc_6m    open_act_il    open_il_12m    open_il_24m  mths_since_rcnt_il  total_bal_il        il_util    open_rv_12m    open_rv_24m     max_bal_bc  \
# count  200000.000000  2.000000e+05  200000.000000  200000.000000  200000.000000  200000.000000       200000.000000  2.000000e+05  200000.000000  200000.000000  200000.000000  200000.000000
# mean      230.022100  1.334342e+05       1.050920       2.714855       0.873715       1.915005           19.761910  3.351007e+04      70.205415       1.262295       2.713755    5505.012450
# std      1775.613015  1.492501e+05       1.189981       2.953508       1.056642       2.005857           25.708152  4.046119e+04      23.289368       1.358994       2.337575    5174.260522
# min         0.000000  0.000000e+00       0.000000       0.000000       0.000000       0.000000            0.000000  0.000000e+00       0.000000       0.000000       0.000000       0.000000
# 25%         0.000000  2.936775e+04       0.000000       1.000000       0.000000       0.000000            6.000000  8.806750e+03      57.000000       0.000000       1.000000    2213.000000
# 50%         0.000000  7.298800e+04       1.000000       2.000000       1.000000       1.000000           12.000000  2.232000e+04      74.000000       1.000000       2.000000    4224.000000
# 75%         0.000000  1.972862e+05       2.000000       3.000000       1.000000       3.000000           22.000000  4.353500e+04      86.000000       2.000000       4.000000    7206.000000
# max    199433.000000  3.258254e+06      16.000000      48.000000      20.000000      39.000000          446.000000  1.547285e+06     558.000000      22.000000      45.000000  301210.000000
#
#             all_util  total_rev_hi_lim         inq_fi    total_cu_tl   inq_last_12m  acc_open_past_24mths    avg_cur_bal  bc_open_to_buy        bc_util  chargeoff_within_12_mths    delinq_amnt  \
# count  200000.000000      2.000000e+05  200000.000000  200000.000000  200000.000000         200000.000000  200000.000000   200000.000000  200000.000000             200000.000000  200000.000000
# mean       61.995210      3.119424e+04       1.167065       1.669000       2.407435              4.898570   12652.200355     9305.872275      61.043219                  0.008975      16.915020
# std        19.674457      3.094635e+04       1.683867       2.932574       2.615008              3.280455   15288.478032    14277.046880      28.251856                  0.104616     943.077677
# min         0.000000      0.000000e+00       0.000000       0.000000       0.000000              0.000000       0.000000        0.000000       0.000000                  0.000000       0.000000
# 25%        50.000000      1.360000e+04       0.000000       0.000000       1.000000              3.000000    3009.000000     1327.000000      39.600000                  0.000000       0.000000
# 50%        64.000000      2.320000e+04       1.000000       0.000000       2.000000              4.000000    6807.000000     4280.000000      64.700000                  0.000000       0.000000
# 75%        76.000000      3.860000e+04       2.000000       2.000000       3.000000              7.000000   17392.250000    11166.000000      86.000000                  0.000000       0.000000
# max       168.000000      1.314900e+06      28.000000      48.000000      32.000000             50.000000  497484.000000   293031.000000     190.600000                  6.000000  249925.000000
#
#        mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl       mort_acc  mths_since_recent_bc  mths_since_recent_inq  mths_since_recent_revol_delinq  \
# count       200000.000000         200000.000000          200000.000000   200000.000000  200000.000000         200000.000000          200000.000000                    200000.00000
# mean           123.496620            177.572560              12.592685        7.572270       1.583020             23.051050               7.020060                        41.13807
# std             53.847389             94.626771              15.829046        8.539039       1.974375             30.106178               6.059382                        21.84772
# min              0.000000              3.000000               0.000000        0.000000       0.000000              0.000000               0.000000                         0.00000
# 25%             93.000000            114.000000               4.000000        3.000000       0.000000              6.000000               2.000000                        24.00000
# 50%            128.000000            160.000000               8.000000        5.000000       1.000000             13.000000               5.000000                        39.00000
# 75%            151.000000            226.000000              15.000000       10.000000       3.000000             27.000000              11.000000                        59.00000
# max            724.000000            804.000000             324.000000      314.000000      32.000000            538.000000              25.000000                       202.00000
#
#        num_accts_ever_120_pd  num_actv_bc_tl    num_bc_sats      num_bc_tl  num_rev_tl_bal_gt_0   num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# count          200000.000000   200000.000000  200000.000000  200000.000000        200000.000000  200000.000000       200000.000000       200000.000000   200000.000000     200000.000000
# mean                0.522660        3.702345       4.719860       7.997870             5.726970       0.003425            0.088390            2.271730       94.162227         46.697567
# std                 1.333422        2.268906       2.960616       4.750692             3.267695       0.062636            0.485539            1.894223        8.728537         36.143285
# min                 0.000000        0.000000       0.000000       0.000000             0.000000       0.000000            0.000000            0.000000        6.700000          0.000000
# 25%                 0.000000        2.000000       3.000000       5.000000             3.000000       0.000000            0.000000            1.000000       91.300000         14.300000
# 50%                 0.000000        3.000000       4.000000       7.000000             5.000000       0.000000            0.000000            2.000000       97.900000         50.000000
# 75%                 0.000000        5.000000       6.000000      10.000000             7.000000       0.000000            0.000000            3.000000      100.000000         75.000000
# max                34.000000       30.000000      46.000000      61.000000            39.000000       4.000000           20.000000           25.000000      100.000000        100.000000
#
#        pub_rec_bankruptcies      tax_liens  total_bc_limit  fico_range_mean  sub_grade_num  emp_length_num
# count         200000.000000  200000.000000   200000.000000    200000.000000  200000.000000   200000.000000
# mean               0.142080       0.054800    20540.207830       695.489473      12.822720        5.946410
# std                0.386451       0.436312    20559.740281        30.408820       6.669401        3.699005
# min                0.000000       0.000000        0.000000       662.000000       1.000000        0.000000
# 25%                0.000000       0.000000     7500.000000       672.000000       8.000000        2.000000
# 50%                0.000000       0.000000    14400.000000       687.000000      12.000000        6.000000
# 75%                0.000000       0.000000    26500.000000       712.000000      17.000000       10.000000
# max                8.000000      85.000000   760000.000000       847.500000      35.000000       10.000000

# %% [markdown]
# ### Extreme outlier

# %%
df_plot = df
label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(df_plot['loan_status'])
df_plot['loan_status'] = label_encoder.transform(df_plot['loan_status'])

# %%
##### "dti" distribution (Outlier) #####
plt.figure(figsize=(10,4))
plt.rcParams['agg.path.chunksize'] = 1000000
plt.subplot(1,2,1)
plt.title('[ Scatter plot for dti & loan_Status ]', fontweight="bold")
plt.scatter('dti', 'loan_status', data=df_plot)
plt.xlabel('dti')
plt.ylabel('Loan Status')

plt.subplot(1,2,2)
plt.hist(df['dti'], bins=1000, color="blue")
plt.title('[ Histogram for dti ]', fontweight="bold")
plt.xlabel('dti')

df.dti.unique().shape
print('shape of data(dti>=600) :', df[df['dti'] >= 600].shape)
# Out:
# shape of data(dti>=600) : (10, 80)

# %%
##### "total_rec_late_fee" distribution (Outlier) #####
plt.figure(figsize=(10,4))
plt.rcParams['agg.path.chunksize'] = 1000000
plt.subplot(1,2,1)
plt.title('[ total_rec_late_fee & loan_Status ]', fontweight="bold")
plt.scatter('total_rec_late_fee', 'loan_status', data=df_plot)
plt.xlabel('total_rec_late_fee')
plt.ylabel('Loan Status')

plt.subplot(1,2,2)
plt.hist(df['total_rec_late_fee'], bins=50, color="blue")
plt.title('[ Histogram for total_rec_late_fee ]', fontweight="bold")
plt.xlabel('total_rec_late_fee')

df.dti.unique().shape
print('shape of data(total_rec_late_fee>=500) :', df[df['total_rec_late_fee'] >= 500].shape)
# Out:
# shape of data(total_rec_late_fee>=500) : (5, 80)

# %%
##### "tot_coll_amt" distribution (Outlier) #####
plt.figure(figsize=(10,4))
plt.rcParams['agg.path.chunksize'] = 1000000
plt.subplot(1,2,1)
plt.title('[ tot_coll_amt & loan_Status ]', fontweight="bold")
plt.scatter('tot_coll_amt', 'loan_status', data=df_plot)
plt.xlabel('tot_coll_amt')
plt.ylabel('Loan Status')

plt.subplot(1,2,2)
plt.hist(df['tot_coll_amt'], bins=80, color="blue")
plt.title('[ Histogram for tot_coll_amt ]', fontweight="bold")
plt.xlabel('tot_coll_amt')

df.dti.unique().shape
print('shape of data(tot_coll_amt>=100000) :', df[df['tot_coll_amt'] >= 100000].shape)
# Out:
# shape of data(tot_coll_amt>=100000) : (6, 80)

# %%
# outlier deletion :  dti (>=600, 10 counts)
print('before outlier(dti) removel : ', df.shape)
df = df[df['dti'] < 600]
print('after outlier(dti) removel : ', df.shape)

df = df[df['total_rec_late_fee'] < 500]
print('after outlier(total_rec_late_fee) removel : ', df.shape)

df = df[df['tot_coll_amt'] < 100000]
print('after outlier(tot_coll_amt) removel : ', df.shape)
# Out:
# before outlier(dti) removel :  (200000, 80)
# after outlier(dti) removel :  (199990, 80)
# after outlier(total_rec_late_fee) removel :  (199985, 80)
# after outlier(tot_coll_amt) removel :  (199979, 80)

# %%
df = df.drop(['recoveries', 'last_pymnt_amnt','last_fico_range_high','last_fico_range_low','total_pymnt'], axis=1)

# %% [markdown]
# ### dummification for categorical variables

# %%
print(df.dtypes.value_counts())
# Out:
# int64      51
# float64    13
# object     11
# dtype: int64

# %%
x_old = df[df.columns.difference(['loan_status'])]
y = df[['loan_status']]

# %%
x = pd.get_dummies(x_old, drop_first=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### 1. Logistic Regression

# %%
log = LogisticRegression()

log.fit(x_train, y_train)

print('training prediction accuracy :  %.2f' % log.score(x_train, y_train))
print('test prediction accuracy :  %.2f' % log.score(x_test, y_test))
print('** test pred before outlier deletion : ', 0.69)
# Out:
# training prediction accuracy :  0.69
# test prediction accuracy :  0.69
# ** test pred before outlier deletion :  0.69

# %%
## same logic (for checking)
lr_log = LogisticRegression()
lr_log.fit(x_train, y_train)
lr_pred = lr_log.predict(x_test)

print('accuracy : %.2f' % accuracy_score(y_test, lr_pred))
print('** test pred before outlier deletion : ', 0.69)
# Out:
# accuracy : 0.69
# ** test pred before outlier deletion :  0.69

# %%
test_pred_prob = lr_log.predict_proba(x_test)
print(roc_auc_score(y_test, test_pred_prob[:,1]))
print('** test pred before outlier deletion : ', 0.747396965817424)
# Out:
# 0.7498263373401799
# ** test pred before outlier deletion :  0.747396965817424

# %% [markdown]
# ### 2. Random Forest

# %% [markdown]
# #### * Before Tuning

# %%
rf_clf = RandomForestClassifier(random_state=1)
rf_clf.fit(x_train, y_train)
rf_pred = rf_clf.predict(x_test)

accuracy = accuracy_score(y_test, rf_pred)
print('rf accuracy : {0:.4f}' .format(accuracy))
print('** accuracy before outlier deletion : ', 0.6685)
# Out:
# rf accuracy : 0.6722
# ** accuracy before outlier deletion :  0.6685

# %% [markdown]
# #### * Hyper Parameter tuning

# %%
### It takes very long ###

from sklearn.model_selection import GridSearchCV

rf2_clf = RandomForestClassifier(random_state=1)
rf_params = {
    'n_estimators': [50, 100],    
    'max_depth': [6,8,10],
    'min_samples_leaf': [8,12,18],
    'min_samples_split': [8,12,18],
    "random_state": [1]
}

# GridSearchCV
rf_grid_cv = GridSearchCV(rf2_clf, param_grid=rf_params, cv=5)
rf_grid_cv.fit(x_train,y_train)

print('best parameter:\n', rf_grid_cv.best_params_)
print('best prediction accuracy: {0:.4f}'.format(rf_grid_cv.best_score_))

# %%
### test with best param + n_estimators increase
rf3_clf = RandomForestClassifier(n_estimators=300, max_depth=10, min_samples_leaf=8,
                                min_samples_split=8, random_state=1)
rf3_clf.fit(x_train, y_train)
rf3_pred = rf3_clf.predict(x_test)

print('rf3 accuracy : {0:.4f}' .format(accuracy_score(y_test, rf3_pred)))
print('** accuracy before outlier deletion : ', 0.7011)
# Out:
# rf3 accuracy : 0.7005
# ** accuracy before outlier deletion :  0.7011

# %%
feature_imp = rf3_clf.feature_importances_
feature_imp = pd.Series(feature_imp, index=x_train.columns)
feature_top20 = feature_imp.sort_values(ascending=False)[:20]
print(feature_top20)

plt.figure(figsize=(8,6))
plt.title('Feature Importance (top20)')
sns.barplot(x=feature_top20, y=feature_top20.index)
plt.show()
# Out:
# debt_settlement_flag_Y    0.183825
# sub_grade_num             0.136014
# int_rate                  0.135239
# total_rec_late_fee        0.095256
# term_ 60 months           0.060878
# fico_range_mean           0.026908
# grade_B                   0.026790
# grade_E                   0.022606
# total_rec_int             0.022093
# dti                       0.020614
# grade_D                   0.016691
# avg_cur_bal               0.015822
# loan_amnt                 0.013737
# grade_C                   0.012729
# bc_open_to_buy            0.012653
# installment               0.012399
# tot_cur_bal               0.010602
# acc_open_past_24mths      0.010364
# grade_F                   0.009606
# annual_inc                0.008628
# dtype: float64

# %% [markdown]
# ### 3. GBM

# %% [markdown]
# #### * Before Tuning

# %%
start_time = time.time()

gb_clf = GradientBoostingClassifier(random_state=1)
gb_clf.fit(x_train, y_train)
gb_pred = gb_clf.predict(x_test)
gb_accuracy = accuracy_score(y_test, gb_pred)

print('gbm accuracy : {0:.4f}'.format(accuracy))
print('gbm running time : {0:.1f} seconds '.format(time.time()-start_time))
print('** accuracy before outlier deletion : ', 0.6685)
# Out:
# gbm accuracy : 0.6722
# gbm running time : 137.4 seconds
# ** accuracy before outlier deletion :  0.6685

# %% [markdown]
# #### * Hyper Parameter tuning

# %%
gb2_clf = GradientBoostingClassifier(random_state=1)
gb_params = {
    'n_estimators': [100,500],
    'learning_rate': [0.05, 0.1]
}

gb_grid_cv = GridSearchCV(gb2_clf, param_grid=gb_params, cv=10, verbose=1)
gb_grid_cv.fit(x_train, y_train)

print('best parameter:\n', gb_grid_cv.best_params_)
print('best prediction accuracy: {0:.4f}'.format(gb_grid_cv.best_score_))
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 168.4min finished
# best parameter:
#  {'learning_rate': 0.1, 'n_estimators': 500}
# best prediction accuracy: 0.7370

# %%
### test with best param 
gb3_pred = gb_grid_cv.best_estimator_.predict(x_test)
gb3_accuracy = accuracy_score(y_test, gb3_pred)

print('GBM accuracy(After tuning) : {0:.4f}' .format(gb3_accuracy))
# Out:
# GBM accuracy(After tuning) : 0.7379

# %%
gb_feature_imp = gb_grid_cv.best_estimator_.feature_importances_
gb_feature_imp = pd.Series(gb_feature_imp, index=x_train.columns)
gb_feature_top20 = gb_feature_imp.sort_values(ascending=False)[:20]
print(gb_feature_top20)

plt.figure(figsize=(8,6))
plt.title('gb_Feature Importance (top20)')
sns.barplot(x=gb_feature_top20, y=gb_feature_top20.index)
plt.show()
# Out:
# sub_grade_num             0.306095
# debt_settlement_flag_Y    0.211962
# total_rec_int             0.120541
# total_rec_late_fee        0.086313
# term_ 60 months           0.049026
# installment               0.034923
# loan_amnt                 0.034915
# int_rate                  0.022657
# dti                       0.014608
# avg_cur_bal               0.014185
# annual_inc                0.009855
# num_rev_tl_bal_gt_0       0.006477
# home_ownership_RENT       0.005752
# fico_range_mean           0.005744
# mo_sin_old_rev_tl_op      0.005398
# acc_open_past_24mths      0.004965
# mort_acc                  0.004167
# open_rv_24m               0.002852
# total_bc_limit            0.002833
# total_rev_hi_lim          0.002816
# dtype: float64

# %% [markdown]
# ### 4. XGBoost

# %%
label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(y_train)
y_train_xgb = label_encoder.transform(y_train)

label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(y_test)
y_test_xgb = label_encoder.transform(y_test)

# %%
dtrain = xgb.DMatrix(data=x_train, label=y_train_xgb)
dtest = xgb.DMatrix(data=x_test, label=y_test_xgb)

# %%
xgb_params = {'max_depth':3, 'eta':0.1, 'objective':'binary:logistic', 'eval_metric':'logloss', 
              'early_stoppings':100}
num_rounds = 400

# %%
wlist = [(dtrain, 'train'), (dtest, 'eval')]
xgb_model = xgb.train(params = xgb_params, dtrain=dtrain, num_boost_round=num_rounds, evals=wlist)
# Out:
# [0]	train-logloss:0.676491	eval-logloss:0.67652
# [1]	train-logloss:0.66268	eval-logloss:0.662951
# [2]	train-logloss:0.650993	eval-logloss:0.651298
# [3]	train-logloss:0.641154	eval-logloss:0.641568
# [4]	train-logloss:0.632793	eval-logloss:0.633238
# [5]	train-logloss:0.625525	eval-logloss:0.626079
# [6]	train-logloss:0.619232	eval-logloss:0.619867
# [7]	train-logloss:0.613797	eval-logloss:0.614576
# [8]	train-logloss:0.609104	eval-logloss:0.609926
# [9]	train-logloss:0.604925	eval-logloss:0.605837
# [10]	train-logloss:0.60126	eval-logloss:0.602291
# [11]	train-logloss:0.598075	eval-logloss:0.599186
# [12]	train-logloss:0.595216	eval-logloss:0.596393
# [13]	train-logloss:0.592318	eval-logloss:0.593564
# [14]	train-logloss:0.589999	eval-logloss:0.59125
# [15]	train-logloss:0.587989	eval-logloss:0.589319
# [16]	train-logloss:0.586	eval-logloss:0.587374
# [17]	train-logloss:0.583892	eval-logloss:0.585371
# [18]	train-logloss:0.582324	eval-logloss:0.583885
# [19]	train-logloss:0.580833	eval-logloss:0.582405
# [20]	train-logloss:0.579259	eval-logloss:0.580915
# [21]	train-logloss:0.57787	eval-logloss:0.579533
# [22]	train-logloss:0.576627	eval-logloss:0.578303
# [23]	train-logloss:0.575354	eval-logloss:0.577153
# [24]	train-logloss:0.574219	eval-logloss:0.57602
# [25]	train-logloss:0.573184	eval-logloss:0.574973
# [26]	train-logloss:0.572219	eval-logloss:0.57398
# [27]	train-logloss:0.571033	eval-logloss:0.572939
# [28]	train-logloss:0.570184	eval-logloss:0.572151
# [29]	train-logloss:0.569278	eval-logloss:0.571259
# [30]	train-logloss:0.568444	eval-logloss:0.570487
# [31]	train-logloss:0.567466	eval-logloss:0.569582
# [32]	train-logloss:0.566763	eval-logloss:0.568932
# [33]	train-logloss:0.566117	eval-logloss:0.568292
# [34]	train-logloss:0.565412	eval-logloss:0.567541
# [35]	train-logloss:0.564754	eval-logloss:0.566987
# [36]	train-logloss:0.564145	eval-logloss:0.566387
# [37]	train-logloss:0.563339	eval-logloss:0.565559
# [38]	train-logloss:0.562795	eval-logloss:0.565026
# [39]	train-logloss:0.562208	eval-logloss:0.56443
# [40]	train-logloss:0.561374	eval-logloss:0.563621
# [41]	train-logloss:0.560838	eval-logloss:0.563189
# [42]	train-logloss:0.56037	eval-logloss:0.562729
# [43]	train-logloss:0.559876	eval-logloss:0.56222
# [44]	train-logloss:0.559058	eval-logloss:0.561458
# [45]	train-logloss:0.558305	eval-logloss:0.560727
# [46]	train-logloss:0.55741	eval-logloss:0.559953
# [47]	train-logloss:0.556953	eval-logloss:0.559543
# [48]	train-logloss:0.556282	eval-logloss:0.558932
# [49]	train-logloss:0.555881	eval-logloss:0.558516
# [50]	train-logloss:0.555197	eval-logloss:0.557839
# [51]	train-logloss:0.554738	eval-logloss:0.557395
# [52]	train-logloss:0.55416	eval-logloss:0.556892
# [53]	train-logloss:0.553815	eval-logloss:0.556582
# [54]	train-logloss:0.552923	eval-logloss:0.555753
# [55]	train-logloss:0.552292	eval-logloss:0.555205
# [56]	train-logloss:0.551552	eval-logloss:0.554461
# [57]	train-logloss:0.550919	eval-logloss:0.553942
# [58]	train-logloss:0.550544	eval-logloss:0.553544
# [59]	train-logloss:0.550244	eval-logloss:0.553253
# [60]	train-logloss:0.549947	eval-logloss:0.552939
# [61]	train-logloss:0.549522	eval-logloss:0.552551
# [62]	train-logloss:0.548968	eval-logloss:0.552041
# [63]	train-logloss:0.548449	eval-logloss:0.551563
# [64]	train-logloss:0.548019	eval-logloss:0.55109
# [65]	train-logloss:0.547629	eval-logloss:0.550715
# [66]	train-logloss:0.547003	eval-logloss:0.550099
# [67]	train-logloss:0.546355	eval-logloss:0.549465
# [68]	train-logloss:0.545887	eval-logloss:0.549058
# [69]	train-logloss:0.545567	eval-logloss:0.548765
# [70]	train-logloss:0.545265	eval-logloss:0.548436
# [71]	train-logloss:0.545039	eval-logloss:0.548234
# [72]	train-logloss:0.544557	eval-logloss:0.547844
# [73]	train-logloss:0.544252	eval-logloss:0.547559
# [74]	train-logloss:0.544029	eval-logloss:0.547321
# [75]	train-logloss:0.543749	eval-logloss:0.547065
# [76]	train-logloss:0.543426	eval-logloss:0.546802
# [77]	train-logloss:0.5429	eval-logloss:0.546297
# [78]	train-logloss:0.542654	eval-logloss:0.546051
# [79]	train-logloss:0.542476	eval-logloss:0.545895
# [80]	train-logloss:0.541851	eval-logloss:0.545273
# [81]	train-logloss:0.541101	eval-logloss:0.544569
# [82]	train-logloss:0.540733	eval-logloss:0.544286
# [83]	train-logloss:0.54022	eval-logloss:0.543858
# [84]	train-logloss:0.539939	eval-logloss:0.543623
# [85]	train-logloss:0.539524	eval-logloss:0.543183
# [86]	train-logloss:0.539273	eval-logloss:0.54294
# [87]	train-logloss:0.538986	eval-logloss:0.542688
# [88]	train-logloss:0.53879	eval-logloss:0.542479
# [89]	train-logloss:0.538586	eval-logloss:0.54233
# [90]	train-logloss:0.538328	eval-logloss:0.542069
# [91]	train-logloss:0.538047	eval-logloss:0.541794
# [92]	train-logloss:0.537883	eval-logloss:0.541615
# [93]	train-logloss:0.537553	eval-logloss:0.541321
# [94]	train-logloss:0.537354	eval-logloss:0.541159
# [95]	train-logloss:0.537122	eval-logloss:0.540916
# [96]	train-logloss:0.536844	eval-logloss:0.540675
# [97]	train-logloss:0.53655	eval-logloss:0.540392
# [98]	train-logloss:0.536407	eval-logloss:0.540242
# [99]	train-logloss:0.536228	eval-logloss:0.540065
# [100]	train-logloss:0.536057	eval-logloss:0.539932
# [101]	train-logloss:0.53584	eval-logloss:0.539767
# [102]	train-logloss:0.535571	eval-logloss:0.539565
# [103]	train-logloss:0.535378	eval-logloss:0.539399
# [104]	train-logloss:0.535259	eval-logloss:0.539251
# [105]	train-logloss:0.535118	eval-logloss:0.539094
# [106]	train-logloss:0.534834	eval-logloss:0.538827
# [107]	train-logloss:0.534688	eval-logloss:0.538721
# [108]	train-logloss:0.534491	eval-logloss:0.538554
# [109]	train-logloss:0.534012	eval-logloss:0.538061
# [110]	train-logloss:0.533884	eval-logloss:0.537937
# [111]	train-logloss:0.533675	eval-logloss:0.537722
# [112]	train-logloss:0.533369	eval-logloss:0.537457
# [113]	train-logloss:0.533246	eval-logloss:0.537338
# [114]	train-logloss:0.532911	eval-logloss:0.537046
# [115]	train-logloss:0.532644	eval-logloss:0.536837
# [116]	train-logloss:0.532432	eval-logloss:0.536653
# [117]	train-logloss:0.532291	eval-logloss:0.536503
# [118]	train-logloss:0.532087	eval-logloss:0.53636
# [119]	train-logloss:0.531959	eval-logloss:0.536242
# [120]	train-logloss:0.531644	eval-logloss:0.535949
# [121]	train-logloss:0.531348	eval-logloss:0.535699
# [122]	train-logloss:0.531038	eval-logloss:0.535386
# [123]	train-logloss:0.530876	eval-logloss:0.535222
# [124]	train-logloss:0.530399	eval-logloss:0.534821
# [125]	train-logloss:0.530162	eval-logloss:0.534574
# [126]	train-logloss:0.530062	eval-logloss:0.534481
# [127]	train-logloss:0.529678	eval-logloss:0.53412
# [128]	train-logloss:0.529526	eval-logloss:0.534016
# [129]	train-logloss:0.529373	eval-logloss:0.533867
# [130]	train-logloss:0.529247	eval-logloss:0.533761
# [131]	train-logloss:0.529126	eval-logloss:0.533674
# [132]	train-logloss:0.529005	eval-logloss:0.533547
# [133]	train-logloss:0.528915	eval-logloss:0.533458
# [134]	train-logloss:0.528822	eval-logloss:0.533379
# [135]	train-logloss:0.528657	eval-logloss:0.533225
# [136]	train-logloss:0.528255	eval-logloss:0.532893
# [137]	train-logloss:0.527962	eval-logloss:0.532632
# [138]	train-logloss:0.527775	eval-logloss:0.532513
# [139]	train-logloss:0.527615	eval-logloss:0.532359
# [140]	train-logloss:0.527411	eval-logloss:0.532186
# [141]	train-logloss:0.527327	eval-logloss:0.532111
# [142]	train-logloss:0.527249	eval-logloss:0.532029
# [143]	train-logloss:0.527128	eval-logloss:0.531905
# [144]	train-logloss:0.526953	eval-logloss:0.531747
# [145]	train-logloss:0.52677	eval-logloss:0.531626
# [146]	train-logloss:0.526578	eval-logloss:0.531484
# [147]	train-logloss:0.52648	eval-logloss:0.531403
# [148]	train-logloss:0.526381	eval-logloss:0.531311
# [149]	train-logloss:0.526286	eval-logloss:0.531244
# [150]	train-logloss:0.526214	eval-logloss:0.53118
# [151]	train-logloss:0.526003	eval-logloss:0.531009
# [152]	train-logloss:0.5258	eval-logloss:0.530825
# [153]	train-logloss:0.525727	eval-logloss:0.530753
# [154]	train-logloss:0.52561	eval-logloss:0.530632
# [155]	train-logloss:0.525445	eval-logloss:0.53051
# [156]	train-logloss:0.525308	eval-logloss:0.530403
# [157]	train-logloss:0.525183	eval-logloss:0.53029
# [158]	train-logloss:0.525049	eval-logloss:0.530171
# [159]	train-logloss:0.524849	eval-logloss:0.529981
# [160]	train-logloss:0.524783	eval-logloss:0.529938
# [161]	train-logloss:0.524573	eval-logloss:0.529739
# [162]	train-logloss:0.524471	eval-logloss:0.529683
# [163]	train-logloss:0.52434	eval-logloss:0.529595
# [164]	train-logloss:0.524265	eval-logloss:0.529532
# [165]	train-logloss:0.52399	eval-logloss:0.529272
# [166]	train-logloss:0.523815	eval-logloss:0.529125
# [167]	train-logloss:0.523709	eval-logloss:0.529045
# [168]	train-logloss:0.523566	eval-logloss:0.528935
# [169]	train-logloss:0.523374	eval-logloss:0.52878
# [170]	train-logloss:0.523275	eval-logloss:0.528717
# [171]	train-logloss:0.523166	eval-logloss:0.528627
# [172]	train-logloss:0.523105	eval-logloss:0.528574
# [173]	train-logloss:0.522826	eval-logloss:0.528306
# [174]	train-logloss:0.522706	eval-logloss:0.528194
# [175]	train-logloss:0.522628	eval-logloss:0.52814
# [176]	train-logloss:0.522514	eval-logloss:0.52805
# [177]	train-logloss:0.522418	eval-logloss:0.528
# [178]	train-logloss:0.52231	eval-logloss:0.527892
# [179]	train-logloss:0.522165	eval-logloss:0.527771
# [180]	train-logloss:0.52211	eval-logloss:0.52773
# [181]	train-logloss:0.521998	eval-logloss:0.52764
# [182]	train-logloss:0.521899	eval-logloss:0.527571
# [183]	train-logloss:0.52185	eval-logloss:0.527523
# [184]	train-logloss:0.521756	eval-logloss:0.527463
# [185]	train-logloss:0.521473	eval-logloss:0.527163
# [186]	train-logloss:0.521404	eval-logloss:0.527115
# [187]	train-logloss:0.521078	eval-logloss:0.526885
# [188]	train-logloss:0.520878	eval-logloss:0.526689
# [189]	train-logloss:0.520828	eval-logloss:0.526651
# [190]	train-logloss:0.520757	eval-logloss:0.526606
# [191]	train-logloss:0.520616	eval-logloss:0.526492
# [192]	train-logloss:0.520483	eval-logloss:0.526405
# [193]	train-logloss:0.520318	eval-logloss:0.526269
# [194]	train-logloss:0.520244	eval-logloss:0.526204
# [195]	train-logloss:0.520155	eval-logloss:0.526136
# [196]	train-logloss:0.519915	eval-logloss:0.525921
# [197]	train-logloss:0.519851	eval-logloss:0.525887
# [198]	train-logloss:0.519771	eval-logloss:0.525841
# [199]	train-logloss:0.51971	eval-logloss:0.525802
# [200]	train-logloss:0.519555	eval-logloss:0.525688
# [201]	train-logloss:0.519465	eval-logloss:0.525597
# [202]	train-logloss:0.5194	eval-logloss:0.525555
# [203]	train-logloss:0.519292	eval-logloss:0.525472
# [204]	train-logloss:0.519176	eval-logloss:0.525374
# [205]	train-logloss:0.51909	eval-logloss:0.525315
# [206]	train-logloss:0.519021	eval-logloss:0.525235
# [207]	train-logloss:0.518914	eval-logloss:0.525156
# [208]	train-logloss:0.518629	eval-logloss:0.524926
# [209]	train-logloss:0.518563	eval-logloss:0.524903
# [210]	train-logloss:0.518497	eval-logloss:0.524855
# [211]	train-logloss:0.518422	eval-logloss:0.524795
# [212]	train-logloss:0.518336	eval-logloss:0.524745
# [213]	train-logloss:0.518274	eval-logloss:0.524697
# [214]	train-logloss:0.518059	eval-logloss:0.524481
# [215]	train-logloss:0.517973	eval-logloss:0.524403
# [216]	train-logloss:0.517721	eval-logloss:0.524223
# [217]	train-logloss:0.517615	eval-logloss:0.524139
# [218]	train-logloss:0.517567	eval-logloss:0.524089
# [219]	train-logloss:0.517464	eval-logloss:0.524011
# [220]	train-logloss:0.517386	eval-logloss:0.523968
# [221]	train-logloss:0.517301	eval-logloss:0.523926
# [222]	train-logloss:0.517216	eval-logloss:0.523857
# [223]	train-logloss:0.517156	eval-logloss:0.523812
# [224]	train-logloss:0.517079	eval-logloss:0.523748
# [225]	train-logloss:0.51704	eval-logloss:0.523718
# [226]	train-logloss:0.516957	eval-logloss:0.52366
# [227]	train-logloss:0.516879	eval-logloss:0.523593
# [228]	train-logloss:0.516627	eval-logloss:0.523353
# [229]	train-logloss:0.516417	eval-logloss:0.523157
# [230]	train-logloss:0.51631	eval-logloss:0.523071
# [231]	train-logloss:0.516244	eval-logloss:0.52304
# [232]	train-logloss:0.516186	eval-logloss:0.522977
# [233]	train-logloss:0.51606	eval-logloss:0.522863
# [234]	train-logloss:0.515988	eval-logloss:0.522789
# [235]	train-logloss:0.515953	eval-logloss:0.522762
# [236]	train-logloss:0.515867	eval-logloss:0.522677
# [237]	train-logloss:0.515796	eval-logloss:0.522601
# [238]	train-logloss:0.515734	eval-logloss:0.522571
# [239]	train-logloss:0.515658	eval-logloss:0.522522
# [240]	train-logloss:0.515607	eval-logloss:0.522522
# [241]	train-logloss:0.515538	eval-logloss:0.522486
# [242]	train-logloss:0.515316	eval-logloss:0.522303
# [243]	train-logloss:0.515239	eval-logloss:0.52226
# [244]	train-logloss:0.515187	eval-logloss:0.522201
# [245]	train-logloss:0.515139	eval-logloss:0.522146
# [246]	train-logloss:0.515077	eval-logloss:0.522114
# [247]	train-logloss:0.515027	eval-logloss:0.522081
# [248]	train-logloss:0.514952	eval-logloss:0.522011
# [249]	train-logloss:0.514841	eval-logloss:0.521933
# [250]	train-logloss:0.514807	eval-logloss:0.521916
# [251]	train-logloss:0.514747	eval-logloss:0.521885
# [252]	train-logloss:0.514689	eval-logloss:0.521866
# [253]	train-logloss:0.51461	eval-logloss:0.521799
# [254]	train-logloss:0.514555	eval-logloss:0.521767
# [255]	train-logloss:0.514354	eval-logloss:0.521641
# [256]	train-logloss:0.514302	eval-logloss:0.521638
# [257]	train-logloss:0.514237	eval-logloss:0.52162
# [258]	train-logloss:0.514022	eval-logloss:0.521409
# [259]	train-logloss:0.513968	eval-logloss:0.521375
# [260]	train-logloss:0.513919	eval-logloss:0.521333
# [261]	train-logloss:0.513758	eval-logloss:0.521209
# [262]	train-logloss:0.513726	eval-logloss:0.521189
# [263]	train-logloss:0.513664	eval-logloss:0.521123
# [264]	train-logloss:0.513583	eval-logloss:0.521058
# [265]	train-logloss:0.513517	eval-logloss:0.521015
# [266]	train-logloss:0.513455	eval-logloss:0.520955
# [267]	train-logloss:0.513377	eval-logloss:0.520877
# [268]	train-logloss:0.51333	eval-logloss:0.52082
# [269]	train-logloss:0.513274	eval-logloss:0.520804
# [270]	train-logloss:0.513141	eval-logloss:0.5207
# [271]	train-logloss:0.513084	eval-logloss:0.520659
# [272]	train-logloss:0.513004	eval-logloss:0.520599
# [273]	train-logloss:0.51296	eval-logloss:0.520572
# [274]	train-logloss:0.512895	eval-logloss:0.520546
# [275]	train-logloss:0.512778	eval-logloss:0.520442
# [276]	train-logloss:0.512696	eval-logloss:0.520368
# [277]	train-logloss:0.512647	eval-logloss:0.520345
# [278]	train-logloss:0.512594	eval-logloss:0.52033
# [279]	train-logloss:0.512531	eval-logloss:0.520297
# [280]	train-logloss:0.512495	eval-logloss:0.520285
# [281]	train-logloss:0.51247	eval-logloss:0.520265
# [282]	train-logloss:0.512441	eval-logloss:0.520234
# [283]	train-logloss:0.512382	eval-logloss:0.520204
# [284]	train-logloss:0.512279	eval-logloss:0.520116
# [285]	train-logloss:0.51211	eval-logloss:0.519958
# [286]	train-logloss:0.512061	eval-logloss:0.519937
# [287]	train-logloss:0.511997	eval-logloss:0.519901
# [288]	train-logloss:0.51193	eval-logloss:0.519848
# [289]	train-logloss:0.511868	eval-logloss:0.519798
# [290]	train-logloss:0.511681	eval-logloss:0.519597
# [291]	train-logloss:0.511586	eval-logloss:0.519524
# [292]	train-logloss:0.51151	eval-logloss:0.519469
# [293]	train-logloss:0.51139	eval-logloss:0.519381
# [294]	train-logloss:0.511257	eval-logloss:0.51925
# [295]	train-logloss:0.511167	eval-logloss:0.519179
# [296]	train-logloss:0.511118	eval-logloss:0.519163
# [297]	train-logloss:0.511054	eval-logloss:0.519114
# [298]	train-logloss:0.510991	eval-logloss:0.519061
# [299]	train-logloss:0.510931	eval-logloss:0.519032
# [300]	train-logloss:0.51089	eval-logloss:0.519009
# [301]	train-logloss:0.510846	eval-logloss:0.518979
# [302]	train-logloss:0.510822	eval-logloss:0.518966
# [303]	train-logloss:0.510783	eval-logloss:0.518943
# [304]	train-logloss:0.510703	eval-logloss:0.518865
# [305]	train-logloss:0.510652	eval-logloss:0.51885
# [306]	train-logloss:0.510596	eval-logloss:0.518818
# [307]	train-logloss:0.510549	eval-logloss:0.51879
# [308]	train-logloss:0.510469	eval-logloss:0.518735
# [309]	train-logloss:0.510425	eval-logloss:0.518716
# [310]	train-logloss:0.510397	eval-logloss:0.518707
# [311]	train-logloss:0.510362	eval-logloss:0.518688
# [312]	train-logloss:0.510321	eval-logloss:0.518648
# [313]	train-logloss:0.51027	eval-logloss:0.518621
# [314]	train-logloss:0.510237	eval-logloss:0.518588
# [315]	train-logloss:0.510206	eval-logloss:0.518561
# [316]	train-logloss:0.510152	eval-logloss:0.518547
# [317]	train-logloss:0.510074	eval-logloss:0.51848
# [318]	train-logloss:0.510015	eval-logloss:0.518452
# [319]	train-logloss:0.509874	eval-logloss:0.518339
# [320]	train-logloss:0.509713	eval-logloss:0.518199
# [321]	train-logloss:0.509611	eval-logloss:0.518118
# [322]	train-logloss:0.509537	eval-logloss:0.518057
# [323]	train-logloss:0.50948	eval-logloss:0.51803
# [324]	train-logloss:0.509425	eval-logloss:0.517982
# [325]	train-logloss:0.509378	eval-logloss:0.517959
# [326]	train-logloss:0.509341	eval-logloss:0.517949
# [327]	train-logloss:0.509193	eval-logloss:0.517859
# [328]	train-logloss:0.509044	eval-logloss:0.517723
# [329]	train-logloss:0.508926	eval-logloss:0.517626
# [330]	train-logloss:0.508852	eval-logloss:0.517572
# [331]	train-logloss:0.508754	eval-logloss:0.517483
# [332]	train-logloss:0.508703	eval-logloss:0.517461
# [333]	train-logloss:0.508654	eval-logloss:0.517437
# [334]	train-logloss:0.508591	eval-logloss:0.517404
# [335]	train-logloss:0.508554	eval-logloss:0.5174
# [336]	train-logloss:0.508507	eval-logloss:0.517377
# [337]	train-logloss:0.50843	eval-logloss:0.517329
# [338]	train-logloss:0.508383	eval-logloss:0.517329
# [339]	train-logloss:0.508332	eval-logloss:0.517281
# [340]	train-logloss:0.508277	eval-logloss:0.517249
# [341]	train-logloss:0.508231	eval-logloss:0.517231
# [342]	train-logloss:0.508183	eval-logloss:0.517208
# [343]	train-logloss:0.508163	eval-logloss:0.517212
# [344]	train-logloss:0.508122	eval-logloss:0.517188
# [345]	train-logloss:0.508087	eval-logloss:0.517159
# [346]	train-logloss:0.508026	eval-logloss:0.517138
# [347]	train-logloss:0.507909	eval-logloss:0.517047
# [348]	train-logloss:0.507849	eval-logloss:0.517019
# [349]	train-logloss:0.507773	eval-logloss:0.516988
# [350]	train-logloss:0.507725	eval-logloss:0.516949
# [351]	train-logloss:0.507667	eval-logloss:0.516934
# [352]	train-logloss:0.507614	eval-logloss:0.516861
# [353]	train-logloss:0.507556	eval-logloss:0.516796
# [354]	train-logloss:0.507483	eval-logloss:0.516754
# [355]	train-logloss:0.507368	eval-logloss:0.516659
# [356]	train-logloss:0.507333	eval-logloss:0.516636
# [357]	train-logloss:0.507291	eval-logloss:0.516592
# [358]	train-logloss:0.507252	eval-logloss:0.51658
# [359]	train-logloss:0.507207	eval-logloss:0.516549
# [360]	train-logloss:0.507165	eval-logloss:0.516524
# [361]	train-logloss:0.507129	eval-logloss:0.516506
# [362]	train-logloss:0.507097	eval-logloss:0.516511
# [363]	train-logloss:0.50706	eval-logloss:0.516491
# [364]	train-logloss:0.50704	eval-logloss:0.51648
# [365]	train-logloss:0.507013	eval-logloss:0.516459
# [366]	train-logloss:0.506956	eval-logloss:0.516413
# [367]	train-logloss:0.506839	eval-logloss:0.516315
# [368]	train-logloss:0.506813	eval-logloss:0.516286
# [369]	train-logloss:0.506781	eval-logloss:0.51626
# [370]	train-logloss:0.506738	eval-logloss:0.516268
# [371]	train-logloss:0.506679	eval-logloss:0.516213
# [372]	train-logloss:0.506643	eval-logloss:0.516188
# [373]	train-logloss:0.506588	eval-logloss:0.516162
# [374]	train-logloss:0.506528	eval-logloss:0.51613
# [375]	train-logloss:0.506435	eval-logloss:0.516057
# [376]	train-logloss:0.506387	eval-logloss:0.516035
# [377]	train-logloss:0.506341	eval-logloss:0.516021
# [378]	train-logloss:0.506297	eval-logloss:0.515999
# [379]	train-logloss:0.506246	eval-logloss:0.515997
# [380]	train-logloss:0.506195	eval-logloss:0.515972
# [381]	train-logloss:0.506146	eval-logloss:0.515948
# [382]	train-logloss:0.506118	eval-logloss:0.515915
# [383]	train-logloss:0.506072	eval-logloss:0.515898
# [384]	train-logloss:0.506027	eval-logloss:0.515882
# [385]	train-logloss:0.505977	eval-logloss:0.515855
# [386]	train-logloss:0.505831	eval-logloss:0.515719
# [387]	train-logloss:0.505779	eval-logloss:0.515686
# [388]	train-logloss:0.505731	eval-logloss:0.515665
# [389]	train-logloss:0.505682	eval-logloss:0.515648
# [390]	train-logloss:0.505584	eval-logloss:0.515594
# [391]	train-logloss:0.505529	eval-logloss:0.515556
# [392]	train-logloss:0.505495	eval-logloss:0.515541
# [393]	train-logloss:0.505455	eval-logloss:0.515508
# [394]	train-logloss:0.50541	eval-logloss:0.515482
# [395]	train-logloss:0.505363	eval-logloss:0.515452
# [396]	train-logloss:0.505322	eval-logloss:0.515446
# [397]	train-logloss:0.505275	eval-logloss:0.51543
# [398]	train-logloss:0.50524	eval-logloss:0.515432
# [399]	train-logloss:0.505196	eval-logloss:0.515423

# %%
pred_probs = xgb_model.predict(dtest)
xgb_preds = [1 if x>0.5 else 0 for x in pred_probs]

# %%
def get_clf_eval(y_test, pred):
    confusion = confusion_matrix(y_test_xgb, pred)
    accuracy = accuracy_score(y_test_xgb , pred)
    precision = precision_score(y_test_xgb , pred)
    recall = recall_score(y_test_xgb , pred)
    print('confusion matrix')
    print(confusion)
    print('Accuracy: {0:.4f}, Precision: {1:.4f}, Recall: {2:.4f}'.format(accuracy , precision ,recall))

# %%
get_clf_eval(y_test_xgb, xgb_preds)
print('** accuracy before outlier deletion : ', 'Accuracy: 0.7345, Precision: 0.7293, Recall: 0.8045')
# Out:
# confusion matrix
# [[12146  6455]
#  [ 4141 17254]]
# Accuracy: 0.7351, Precision: 0.7277, Recall: 0.8065
# ** accuracy before outlier deletion :  Accuracy: 0.7345, Precision: 0.7293, Recall: 0.8045

# %%
fig, ax = plt.subplots(figsize=(12,18))
plt.title('XGB_Feature Importance (top50)')
xgb.plot_importance(xgb_model, max_num_features=50, height=0.8, ax=ax)
plt.show()
